# %% [markdown]
# # Retrieving data from Kiva API

# %% [markdown]
# We will be using [KIVA](https://www.kiva.org/) data for the entirety of this course. Kiva makes it's data publically available through it's [API](http://build.kiva.org/).
#
# Not sure what an API is? It stands for Application Program Interface. Code Academy has a fantastic short course (link [here](https://www.codecademy.com/en/tracks/placekitten) that introduces you to APIs and allows you to pull images of kittens from a website by the end of the session.
#
# Below, we import the packages we need in order to retrieve data from the API.
#
# ** Do we need to explain what packages are? **

# %%
from urllib.request import urlopen, Request
import json
from pandas.io.json import json_normalize
import pandas as pd
import json
import requests as r
import os
import logging

# %% [markdown]
# In the cell below we set the maximum number of columns to 100 so we can see our entire data set. If we did not set this option, we would not be able to see some columns in our dataset.

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# Using % in the section below indicates a magic command. You can find out more about magic commands [here](https://ipython.org/ipython-doc/3/interactive/magics.html). Using the % in the block of code below allows us to run commands on the terminal from within jupyter. We make a folder in our user directory where we will store the data we retrieve from the api.

# %%
% mkdir ~/_intro_machine_learning_course
% cd ~/_intro_machine_learning_course
% pwd
% ls

# %% [markdown]
# In the line below, we create a data cache. A cache is a great way to store data, when it is costly to retrive it from scratch every time.

# %%
store = pd.HDFStore('kiva_cache.h5')

# %% [markdown]
# There is great documentation on Kiva's API [here](http://build.kiva.org/api). The documentation explains what parameters (conditions) we need to pass in our request to Kiva's database in order to get the data we want.
#
# We are trying to retrive all Kiva data from Kenya. So we will be using two main parameters where we set country_code=KE (KE is the two letter [ISO](https://en.wikipedia.org/wiki/ISO_3166-2) code for Kenya), and we increase the results per page to 500 (this is the maximum KIVAs API appears to allow). You can see the HTML results of the api call by pasting the url below into your browser, HTML is a format that is really easy to read.
#
# http://api.kivaws.org/v1/loans/search/?country_code=KE&per_page=500
#
# 1) Go ahead and play with the url in order to retrieve different data. For example, how would you retrieve data from South Africa (ZA)?
#
# 2) How would you only retrive 200 results?
#
# Answers:
#
# 1) http://api.kivaws.org/v1/loans/search/?country_code=ZA&per_page=500
#
# 2)  http://api.kivaws.org/v1/loans/search/?country_code=ZA&per_page=200

# %% [markdown]
# We want to request this data from the api and store it in a format that is more intuitive to us - a dataframe. Let's get started. The code below retrieves the first 500 results and converts it into a pandas dataframe. You will get to know a lot more about dataframes over the next few classes.

# %%
d = r.get('http://api.kivaws.org/v1/loans/search.json?country_code=KE&per_page=500')

# %% [markdown]
# Notice that in the request above we specify json as the type of text we want returned. This is easier to handle and change into a python dataframe. You can past the link into your browser to understand the difference between [JSON](https://en.wikipedia.org/wiki/JSON) and [HTML](https://en.wikipedia.org/wiki/HTML).

# %% [markdown]
# By running d.headers below we can see all the data associated with our request. It shows the time of our request, the fact that we are requesting json text 'Content-Type': 'application/json; charset=UTF-8', in addition to other details.

# %%
d.headers
# Out:
# {'Date': 'Wed, 03 May 2017 23:56:20 GMT', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Access-Control-Allow-Origin': '*', 'Expires': 'Tue, 03 Jul 2001 06:00:00 GMT', 'Last-Modified': 'Wed, 03 May 2017 23:56:20 GMT', 'Cache-Control': 'private, no-store, no-cache, must-revalidate, max-age=0, post-check=0, pre-check=0, proxy-revalidate, no-transform', 'Pragma': 'no-cache', 'X-RateLimit-Overall-Limit': '60', 'X-RateLimit-Overall-Remaining': '60', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '26111', 'Content-Type': 'application/json; charset=UTF-8'}

# %% [markdown]
# By running the command d.json() below we can get an idea of what our data looks like before we change it into a pandas data frame.

# %%
d.json()
# Out:
# {'loans': [{'activity': 'General Store',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1281723,
#    'image': {'id': 2497094, 'template_id': 1},
#    'lender_count': 11,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsabet'},
#    'name': 'Patrick',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-28T04:50:02Z',
#    'posted_date': '2017-04-28T04:50:02Z',
#    'sector': 'Retail',
#    'status': 'funded',
#    'tags': [{'name': '#Widowed'}, {'name': '#Elderly'}, {'name': '#Parent'}],
#    'use': 'to purchase maize seeds, fertilizers, sugar and rice for his shop.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1281570,
#    'image': {'id': 2502890, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Rabecca',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-28T02:20:02Z',
#    'posted_date': '2017-04-28T02:20:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fertilizers, pesticides and herbicides.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281588,
#    'image': {'id': 2502914, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Grace',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T23:40:05Z',
#    'posted_date': '2017-04-27T23:40:05Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fertilizers, pesticides and herbicides.'},
#   {'activity': 'Primary/secondary school costs',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 350,
#    'id': 1281595,
#    'image': {'id': 2494294, 'template_id': 1},
#    'lender_count': 10,
#    'loan_amount': 350,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsabet'},
#    'name': 'Gladys',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-27T23:40:02Z',
#    'posted_date': '2017-04-27T23:40:02Z',
#    'sector': 'Education',
#    'status': 'funded',
#    'tags': [{'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to pay school fees for her children.'},
#   {'activity': 'Farm Supplies',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281568,
#    'image': {'id': 2502887, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Molo'},
#    'name': 'Benson',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T23:00:03Z',
#    'posted_date': '2017-04-27T23:00:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy quality farm supplies like seeds, fertilizer, herbicides and pesticides to help his farming business.'},
#   {'activity': 'Cereals',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281535,
#    'image': {'id': 2502848, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nandi Hills'},
#    'name': 'Betty',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T22:50:03Z',
#    'posted_date': '2017-04-27T22:50:03Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy cereal.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281556,
#    'image': {'id': 2502875, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Loice',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T22:50:03Z',
#    'posted_date': '2017-04-27T22:50:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281546,
#    'image': {'id': 2502860, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsowar'},
#    'name': 'Emily',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T22:30:03Z',
#    'posted_date': '2017-04-27T22:30:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and to start horticulture farming.'},
#   {'activity': 'Poultry',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281521,
#    'image': {'id': 2502838, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Eunice',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T22:20:08Z',
#    'posted_date': '2017-04-27T22:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'Eunice to get into the poultry business.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281510,
#    'image': {'id': 2502829, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Molo'},
#    'name': 'Winny',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T22:00:03Z',
#    'posted_date': '2017-04-27T22:00:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Biz Durable Asset'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm implements and inputs.'},
#   {'activity': 'Primary/secondary school costs',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 500,
#    'id': 1281494,
#    'image': {'id': 2502810, 'template_id': 1},
#    'lender_count': 13,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nkubu'},
#    'name': 'Lilian',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T21:30:05Z',
#    'posted_date': '2017-04-27T21:30:05Z',
#    'sector': 'Education',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'}, {'name': '#Schooling'}],
#    'use': 'to pay tuition fees for her children.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1281484,
#    'image': {'id': 2502793, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Silver',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T21:00:05Z',
#    'posted_date': '2017-04-27T21:00:05Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy poultry and start a new enterprise.'},
#   {'activity': 'Tailoring',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281458,
#    'image': {'id': 2502761, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 925,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.716667 36.433333', 'type': 'point'},
#     'town': 'Naivasha'},
#    'name': 'Emily',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T20:40:02Z',
#    'posted_date': '2017-04-27T20:40:02Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Fabrics'}],
#    'use': 'to buy more tailoring materials.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 25,
#    'id': 1281449,
#    'image': {'id': 2502753, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nyahururu'},
#    'name': 'Hudson',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T20:30:05Z',
#    'posted_date': '2017-04-27T20:30:05Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs.'},
#   {'activity': 'Poultry',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281410,
#    'image': {'id': 2502711, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Macdalena',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T20:20:04Z',
#    'posted_date': '2017-04-27T20:20:05Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy additional breeds of poultry.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281377,
#    'image': {'id': 2502666, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.333333 37.65', 'type': 'point'},
#     'town': 'Chuka'},
#    'name': 'Elosy',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T19:50:06Z',
#    'posted_date': '2017-04-27T19:50:06Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and farm supplies in order to improve her horticulture farm.'},
#   {'activity': 'Dairy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 250,
#    'id': 1281436,
#    'image': {'id': 2502740, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 250,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.333333 37.65', 'type': 'point'},
#     'town': 'Chuka'},
#    'name': 'James',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T19:50:06Z',
#    'posted_date': '2017-04-27T19:50:06Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy a dairy goat.'},
#   {'activity': 'Dairy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281403,
#    'image': {'id': 2502706, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.333333 37.65', 'type': 'point'},
#     'town': 'Chuka'},
#    'name': 'Alice',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T19:30:03Z',
#    'posted_date': '2017-04-27T19:30:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy a dairy goat.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281383,
#    'image': {'id': 2502671, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Caroline',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T19:10:07Z',
#    'posted_date': '2017-04-27T19:10:07Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs (fertilizers, pesticides and herbicides).'},
#   {'activity': 'Restaurant',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1279030,
#    'image': {'id': 2495367, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Musyoki',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-27T19:10:04Z',
#    'posted_date': '2017-04-27T19:10:04Z',
#    'sector': 'Food',
#    'status': 'funded',
#    'tags': [{'name': '#Elderly'}],
#    'use': 'to buy stock of sugar, milk, tea leaves, rice, beans, peas, cooking oil, wood fuel, maize and wheat flour, etc. for the restaurant.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1278834,
#    'image': {'id': 2498892, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.566667 34.566667', 'type': 'point'},
#     'town': 'Bungoma'},
#    'name': 'Sabenzia',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T19:00:03Z',
#    'posted_date': '2017-04-27T19:00:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to stock her new grocery store.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 825,
#    'id': 1281363,
#    'image': {'id': 2502641, 'template_id': 1},
#    'lender_count': 18,
#    'loan_amount': 825,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Limuru'},
#    'name': 'Mary',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T19:00:03Z',
#    'posted_date': '2017-04-27T19:00:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Animals'},
#     {'name': '#Biz Durable Asset'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy a dairy cow.'},
#   {'activity': 'Dairy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 175,
#    'id': 1281336,
#    'image': {'id': 2502606, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.333333 37.65', 'type': 'point'},
#     'town': 'Chuka'},
#    'name': 'Faith',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T18:50:04Z',
#    'posted_date': '2017-04-27T18:50:04Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Animals'},
#     {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy a dairy goat.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281353,
#    'image': {'id': 2502622, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Eliza',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T18:50:04Z',
#    'posted_date': '2017-04-27T18:50:04Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fertilizers, pesticides, and herbicides.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281351,
#    'image': {'id': 2502618, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kerugoya'},
#    'name': 'Pauline',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T18:40:04Z',
#    'posted_date': '2017-04-27T18:40:05Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds in order to improve her horticulture farming.'},
#   {'activity': 'Animal Sales',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281302,
#    'image': {'id': 2502571, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Josephat',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:40:02Z',
#    'posted_date': '2017-04-27T18:40:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Animals'}],
#    'use': 'to buy more cows.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281291,
#    'image': {'id': 2502565, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 875,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.683333 34.766667', 'type': 'point'},
#     'town': 'Kisii'},
#    'name': 'Charles',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:30:02Z',
#    'posted_date': '2017-04-27T18:30:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of bread, flour, sugar, salt and other items.'},
#   {'activity': 'Tailoring',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1281293,
#    'image': {'id': 2502566, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.683333 34.766667', 'type': 'point'},
#     'town': 'Kisii'},
#    'name': 'Elizabeth',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:30:02Z',
#    'posted_date': '2017-04-27T18:30:02Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Fabrics'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of tailoring materials.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281288,
#    'image': {'id': 2502561, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.416667 34.25', 'type': 'point'},
#     'town': 'Busia'},
#    'name': 'Eunice',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:20:03Z',
#    'posted_date': '2017-04-27T18:20:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Animals'},
#     {'name': '#Parent'}],
#    'use': 'to buy more stock of pesticides, fertilizer and animal feed.'},
#   {'activity': 'Fish Selling',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281289,
#    'image': {'id': 2502562, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.416667 34.25', 'type': 'point'},
#     'town': 'Busia'},
#    'name': 'Robert',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:20:03Z',
#    'posted_date': '2017-04-27T18:20:03Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of fish.'},
#   {'activity': 'Clothing Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281280,
#    'image': {'id': 2502548, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.416667 34.25', 'type': 'point'},
#     'town': 'Busia'},
#    'name': 'Emily',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:10:02Z',
#    'posted_date': '2017-04-27T18:10:02Z',
#    'sector': 'Clothing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of clothes.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281257,
#    'image': {'id': 2502519, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsowar'},
#    'name': 'Eliseba',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T18:00:05Z',
#    'posted_date': '2017-04-27T18:00:05Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and fertilizers to expand her horticultural enterprise.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281335,
#    'image': {'id': 2502604, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': "Murang'a"},
#    'name': 'Jane',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T18:00:02Z',
#    'posted_date': '2017-04-27T18:00:02Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs to boost production.'},
#   {'activity': 'Cloth & Dressmaking Supplies',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281321,
#    'image': {'id': 2502592, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Rose',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:50:02Z',
#    'posted_date': '2017-04-27T17:50:02Z',
#    'sector': 'Retail',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Fabrics'}],
#    'use': 'to buy more inventory of cloth.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1281332,
#    'image': {'id': 2502601, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': "Murang'a"},
#    'name': 'Joel',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:50:02Z',
#    'posted_date': '2017-04-27T17:50:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'}, {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs to boost production.'},
#   {'activity': 'Tailoring',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 500,
#    'id': 1281333,
#    'image': {'id': 2502602, 'template_id': 1},
#    'lender_count': 17,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Annastancia',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:50:02Z',
#    'posted_date': '2017-04-27T17:50:02Z',
#    'sector': 'Services',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Fabrics'}],
#    'use': 'to buy more materials for making clothes.'},
#   {'activity': 'Restaurant',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281316,
#    'image': {'id': 2502587, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Fortunata',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:40:02Z',
#    'posted_date': '2017-04-27T17:40:02Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of ingredients for preparing food.'},
#   {'activity': 'Tailoring',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1281329,
#    'image': {'id': 2502596, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 975,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.416667 34.25', 'type': 'point'},
#     'town': 'Busia'},
#    'name': 'Sylvester',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:40:02Z',
#    'posted_date': '2017-04-27T17:40:02Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Fabrics'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy tailoring materials.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281330,
#    'image': {'id': 2502599, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 975,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Moses',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:40:02Z',
#    'posted_date': '2017-04-27T17:40:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of cereals.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281314,
#    'image': {'id': 2502584, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Molo'},
#    'name': 'Pamela',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:30:04Z',
#    'posted_date': '2017-04-27T17:30:04Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds for planting.'},
#   {'activity': 'Shoe Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1281315,
#    'image': {'id': 2502585, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Molo'},
#    'name': 'Mary',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:30:04Z',
#    'posted_date': '2017-04-27T17:30:04Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more shoes.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1281323,
#    'image': {'id': 2502593, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Timothy',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:30:04Z',
#    'posted_date': '2017-04-27T17:30:04Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}],
#    'use': 'to buy more stock of motorcycle spare parts.'},
#   {'activity': 'Agriculture',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281325,
#    'image': {'id': 2502594, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Eva',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:30:04Z',
#    'posted_date': '2017-04-27T17:30:04Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': 'volunteer_pick'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm supplies to boost production for her business selling bananas and other crops.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281313,
#    'image': {'id': 2502583, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': "Murang'a"},
#    'name': 'Margaret',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T17:10:03Z',
#    'posted_date': '2017-04-27T17:10:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs to boost production.'},
#   {'activity': 'Food Market',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1281311,
#    'image': {'id': 2502581, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Mary',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T16:40:02Z',
#    'posted_date': '2017-04-27T16:40:02Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of cereals and vegetables.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281310,
#    'image': {'id': 2502580, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nyahururu'},
#    'name': 'Salome',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T16:30:05Z',
#    'posted_date': '2017-04-27T16:30:05Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to venture into other areas of farming like horticulture to help educate her family.'},
#   {'activity': 'Agriculture',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1281307,
#    'image': {'id': 2502577, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': "Murang'a"},
#    'name': 'Grace',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T16:20:04Z',
#    'posted_date': '2017-04-27T16:20:04Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Animals'},
#     {'name': '#Repeat Borrower'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs to boost production and also add livestock.'},
#   {'activity': 'Clothing Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281308,
#    'image': {'id': 2502578, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Flora',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T16:20:04Z',
#    'posted_date': '2017-04-27T16:20:04Z',
#    'sector': 'Clothing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of clothes.'},
#   {'activity': 'Food',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281319,
#    'image': {'id': 2502589, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Christina',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T16:20:04Z',
#    'posted_date': '2017-04-27T16:20:04Z',
#    'sector': 'Food',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'}],
#    'use': 'to buy more vegetables and cereals to sell.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281304,
#    'image': {'id': 2502574, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.683333 34.766667', 'type': 'point'},
#     'town': 'Kisii'},
#    'name': 'Catherine',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T16:10:04Z',
#    'posted_date': '2017-04-27T16:10:04Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more bread, flour, soap, salt, and other items.'},
#   {'activity': 'Clothing Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281306,
#    'image': {'id': 2502576, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 775,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Millicent',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T16:10:04Z',
#    'posted_date': '2017-04-27T16:10:04Z',
#    'sector': 'Clothing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more clothes to sell.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281303,
#    'image': {'id': 2502573, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.416667 34.25', 'type': 'point'},
#     'town': 'Busia'},
#    'name': 'Florence',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T15:40:04Z',
#    'posted_date': '2017-04-27T15:40:04Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'her to buy more vegetables to sell.'},
#   {'activity': 'Services',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281301,
#    'image': {'id': 2502569, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 700,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Dennis',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T15:30:04Z',
#    'posted_date': '2017-04-27T15:30:04Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'use': 'him to add more M-pesa money transfer services.'},
#   {'activity': 'Agriculture',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 500,
#    'id': 1281283,
#    'image': {'id': 2502557, 'template_id': 1},
#    'lender_count': 12,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kericho'},
#    'name': 'Rodah',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T15:10:03Z',
#    'posted_date': '2017-04-27T15:10:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'her to buy farm supplies to increase the size of her crop.'},
#   {'activity': 'Tailoring',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281286,
#    'image': {'id': 2502559, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kericho'},
#    'name': 'Fredrick',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T15:00:05Z',
#    'posted_date': '2017-04-27T15:00:05Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Fabrics'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of tailoring materials.'},
#   {'activity': 'Grocery Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 175,
#    'id': 1281275,
#    'image': {'id': 2502545, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 350,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsowar'},
#    'name': 'Norah',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T14:40:04Z',
#    'posted_date': '2017-04-27T14:40:04Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Schooling'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fruits and vegetables and start a grocery store.'},
#   {'activity': 'Services',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281276,
#    'image': {'id': 2502543, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.983333 34.25', 'type': 'point'},
#     'town': 'Migori'},
#    'name': 'Esther',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T14:40:03Z',
#    'posted_date': '2017-04-27T14:40:03Z',
#    'sector': 'Services',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'}],
#    'use': 'to buy more stock of maize for milling.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1281273,
#    'image': {'id': 2502540, 'template_id': 1},
#    'lender_count': 3,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.333333 37.65', 'type': 'point'},
#     'town': 'Chuka'},
#    'name': 'Haron',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T14:30:03Z',
#    'posted_date': '2017-04-27T14:30:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Supporting Family'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and start horticulture farming.'},
#   {'activity': 'Clothing Sales',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281274,
#    'image': {'id': 2502541, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Gloria',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T14:20:05Z',
#    'posted_date': '2017-04-27T14:20:05Z',
#    'sector': 'Clothing',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'}],
#    'use': 'to buy more stock of clothes.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281263,
#    'image': {'id': 2502528, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsowar'},
#    'name': 'Dorcas',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-27T14:10:03Z',
#    'posted_date': '2017-04-27T14:10:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and fertilizers.'},
#   {'activity': 'Retail',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281267,
#    'image': {'id': 2502534, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Taveta'},
#    'name': 'Sisilia',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-27T14:10:03Z',
#    'posted_date': '2017-04-27T14:10:03Z',
#    'sector': 'Retail',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of bread, flour, soap, sugar and other items.'},
#   {'activity': 'Retail',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1281268,
#    'image': {'id': 2502535, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
# ...
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1277607,
#    'image': {'id': 2497077, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nandi Hills'},
#    'name': 'Beatrice',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T17:40:03Z',
#    'posted_date': '2017-04-22T17:40:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy high quality farm inputs such as fertilizers, pesticides and herbicides.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1277601,
#    'image': {'id': 2497070, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 975,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-4.05 39.666667', 'type': 'point'},
#     'town': 'Mombasa'},
#    'name': 'Margaret',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-22T17:30:02Z',
#    'posted_date': '2017-04-22T17:30:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of sugar, bread, flour, soap, cereals and other items.'},
#   {'activity': 'Poultry',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1277604,
#    'image': {'id': 2497075, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Siongiroi'},
#    'name': 'Judy',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T17:30:02Z',
#    'posted_date': '2017-04-22T17:30:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to start a poutry farming enterprise in her farm.'},
#   {'activity': 'Beauty Salon',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1277577,
#    'image': {'id': 2497044, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kisauni'},
#    'name': 'Nancy',
#    'partner_id': 164,
#    'planned_expiration_date': '2017-05-22T17:20:06Z',
#    'posted_date': '2017-04-22T17:20:06Z',
#    'sector': 'Services',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'use': 'to purchase chemicals and hair conditioners for her beauty salon business.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1277580,
#    'image': {'id': 2497050, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.283333 36.066667', 'type': 'point'},
#     'town': 'Nakuru'},
#    'name': 'Margaret',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T17:20:05Z',
#    'posted_date': '2017-04-22T17:20:06Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'Margaret to buy farm inputs.'},
#   {'activity': 'Metal Shop',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1277575,
#    'image': {'id': 2497040, 'template_id': 1},
#    'lender_count': 10,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-4.05 39.666667', 'type': 'point'},
#     'town': 'Mombasa'},
#    'name': 'Mwaroja',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-22T17:00:03Z',
#    'posted_date': '2017-04-22T17:00:03Z',
#    'sector': 'Manufacturing',
#    'status': 'funded',
#    'tags': [{'name': '#Parent'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy materials for his welding business.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1277568,
#    'image': {'id': 2497033, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.283333 36.066667', 'type': 'point'},
#     'town': 'Nakuru'},
#    'name': 'Margaret',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T16:50:04Z',
#    'posted_date': '2017-04-22T16:50:04Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Widowed'},
#     {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs such as fertilizer and seeds to start farming and provide a better life for her children.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1277536,
#    'image': {'id': 2496982, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Ann',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T16:40:06Z',
#    'posted_date': '2017-04-22T16:40:06Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'}, {'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs (fertilizers, pesticides and herbicides).'},
#   {'activity': 'Taxi',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 500,
#    'id': 1277567,
#    'image': {'id': 2497032, 'template_id': 1},
#    'lender_count': 18,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.1 34.75', 'type': 'point'},
#     'town': 'Kisumu'},
#    'name': 'James',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-22T16:40:03Z',
#    'posted_date': '2017-04-22T16:40:03Z',
#    'sector': 'Transportation',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Parent'},
#     {'name': '#Repair Renew Replace'}],
#    'use': 'to repair and maintain taxi.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1277559,
#    'image': {'id': 2497020, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Abraham',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-22T16:30:02Z',
#    'posted_date': '2017-04-22T16:30:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of bread, flour, soap, sugar and other items.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 75,
#    'id': 1277554,
#    'image': {'id': 2497011, 'template_id': 1},
#    'lender_count': 3,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Bomet'},
#    'name': 'Joyce',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T16:20:07Z',
#    'posted_date': '2017-04-22T16:20:07Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': 'volunteer_pick'}, {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to purchase farming inputs (fertilizers, pesticides, and herbicides).'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1277548,
#    'image': {'id': 2497003, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nyamira'},
#    'name': 'Hellen',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T16:00:07Z',
#    'posted_date': '2017-04-22T16:00:07Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and start horticultural farming.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1277532,
#    'image': {'id': 2496977, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kerugoya'},
#    'name': 'Florence',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T15:50:02Z',
#    'posted_date': '2017-04-22T15:50:02Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and start horticulture farming.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1277507,
#    'image': {'id': 2496954, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kerugoya'},
#    'name': 'Mary',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T15:40:04Z',
#    'posted_date': '2017-04-22T15:40:04Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds so that the borrower can expand her horticulture farming.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1277522,
#    'image': {'id': 2496967, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-3.216667 40.116667', 'type': 'point'},
#     'town': 'malindi'},
#    'name': 'Susan',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-22T15:30:03Z',
#    'posted_date': '2017-04-22T15:30:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of bread, flour, sugar, beverages, and other items.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1277518,
#    'image': {'id': 2496966, 'template_id': 1},
#    'lender_count': 3,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kerugoya'},
#    'name': 'Joseph',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T15:20:06Z',
#    'posted_date': '2017-04-22T15:20:06Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and expand his horticulture farming.'},
#   {'activity': 'Renewable Energy Products',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50000,
#    'id': 1283951,
#    'image': {'id': 2505671, 'template_id': 1},
#    'lender_count': 1170,
#    'loan_amount': 50000,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-1.283333 36.816667', 'type': 'point'},
#     'town': 'Nairobi'},
#    'name': 'Pawame',
#    'partner_id': 526,
#    'planned_expiration_date': '2017-05-22T15:10:07Z',
#    'posted_date': '2017-04-22T15:10:07Z',
#    'sector': 'Retail',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Technology'}],
#    'themes': ['Green',
#     'Social Enterprise',
#     'SME',
#     'Earth Day Campaign',
#     'Earth Day Campaign'],
#    'use': 'to distribute 400 pay-as-you-go solar home systems in Kenya.'},
#   {'activity': 'Home Products Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1277497,
#    'image': {'id': 2496940, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 975,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-4.05 39.666667', 'type': 'point'},
#     'town': 'Mombasa'},
#    'name': 'Harriet',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-22T15:10:03Z',
#    'posted_date': '2017-04-22T15:10:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of mattresses, suitcases, plastic containers and other items.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 125,
#    'id': 1277490,
#    'image': {'id': 2496930, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Agnes',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T15:00:05Z',
#    'posted_date': '2017-04-22T15:00:05Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Elderly'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs, fertilizers, pesticides, and herbicides.'},
#   {'activity': 'Primary/secondary school costs',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1277493,
#    'image': {'id': 2496935, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Bomet'},
#    'name': 'Janet',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-22T15:00:05Z',
#    'posted_date': '2017-04-22T15:00:05Z',
#    'sector': 'Education',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'}, {'name': '#Schooling'}],
#    'use': 'to pay school fees for her children.'}],
#  'paging': {'page': 2, 'page_size': 500, 'pages': 256, 'total': 127531}}

# %%
data = json.loads(d.text)

# %%
loans=json_normalize(data['loans'])

# %%
loans.head(3)
# Out:
#         activity  basket_amount bonus_credit_eligibility  borrower_count  \
# 0  General Store            NaN                    False               1
# 1        Farming            NaN                    False               1
# 2        Farming            0.0                    False               1
#
#   description.languages  funded_amount       id  image.id  image.template_id  \
# 0                  [en]            300  1281723   2497094                  1
# 1                  [en]            100  1281570   2502890                  1
# 2                  [en]              0  1281588   2502914                  1
#
#    lender_count                        ...                          \
# 0            11                        ...
# 1             4                        ...
# 2             0                        ...
#
#    location.town     name partner_id planned_expiration_date  \
# 0       Kapsabet  Patrick        133    2017-05-28T04:50:02Z
# 1         Kitale  Rabecca        156    2017-05-28T02:20:02Z
# 2         Kitale    Grace        156    2017-05-27T23:40:05Z
#
#             posted_date       sector       status  \
# 0  2017-04-28T04:50:02Z       Retail       funded
# 1  2017-04-28T02:20:02Z  Agriculture       funded
# 2  2017-04-27T23:40:05Z  Agriculture  fundraising
#
#                                                 tags             themes  \
# 0  [{'name': '#Widowed'}, {'name': '#Elderly'}, {...                NaN
# 1                              [{'name': '#Parent'}]  [Rural Exclusion]
# 2                     [{'name': '#Woman Owned Biz'}]  [Rural Exclusion]
#
#                                                  use
# 0  to purchase maize seeds, fertilizers, sugar an...
# 1     to buy fertilizers, pesticides and herbicides.
# 2     to buy fertilizers, pesticides and herbicides.
#
# [3 rows x 26 columns]

# %% [markdown]
# We have now extracted the first 500 rows of loans from the API. We can confirm how many rows we have in a dataset using the len() function below. Now, we need to extract this data more systematically for all Kenyan loan results. KIVA has a parameter called page but does not allow for range of pages, so we will have to create a python loop to go through each page of results and add to our dataset.

# %%
len(loans.index)
# Out:
# 500

# %%
    # Should you put an explaination of the function.
    # ie: Create a dataframe to fill in along the way
    # - go through each page
    # - load data as a text
    # - etc etc

# %%
def extract_loans(pages,country_iso_code):
    loans_full=pd.DataFrame()
    for n in range(1, pages+1):
        s=str(n)
        print(s)
        d = r.get('http://api.kivaws.org/v1/loans/search.json?country_code='+country_iso_code+'&per_page=500&page='+s)
        data = json.loads(d.text)
        loans=json_normalize(data['loans'])
        loans_full=loans_full.append(loans,ignore_index=True)
        print(len(loans_full.index)) 
        
    return loans_full

# %%
loans_full = extract_data(10,'KE')
# Out:
# 1
# 500
# 2
# 1000
# 3
# 1500
# 4
# 2000
# 5
# 2500
# 6
# 3000
# 7
# 3500
# 8
# 4000
# 9
# 4500
# 10
# 5000

# %%
len(loans_full.index)
# Out:
# 5000

# %%
# more comments of what is happening here - being unfamiliar with APIs, Im not sure what is happening
w_lender=loans_full.loc[loans_full['lender_count'] >= 1]
w_lender_list= w_lender['id'].tolist()
w_lender.head(2)
w_lender_list[1]

# %% [markdown]
# We want to cache loans_full locally so we do not have to pull this data again every lesson.

# %%
store['loans']=loans_full
loans_full=store.get('loans')
# Out:
# /Users/Sara/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->['activity', 'description.languages', 'location.country', 'location.country_code', 'location.geo.level', 'location.geo.pairs', 'location.geo.type', 'location.town', 'name', 'planned_expiration_date', 'posted_date', 'sector', 'status', 'tags', 'themes', 'use']]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(loans_full.index)
# Out:
# 5000
