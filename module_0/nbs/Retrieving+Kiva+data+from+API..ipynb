# %% [markdown]
# # Retrieving data from Kiva API

# %% [markdown]
# We will be using [KIVA](https://www.kiva.org/) data for the entirety of this course. Kiva makes it's data publically available through it's [API](http://build.kiva.org/).
#
# Not sure what an API is? It stands for Application Program Interface. Code Academy has a fantastic short course (link [here](https://www.codecademy.com/en/tracks/placekitten) that introduces you to APIs and allows you to pull images of kittens from a website by the end of the session.
#
# Below, we import the packages we need in order to retrieve data from the API.

# %%
from urllib.request import urlopen, Request
import json
from pandas.io.json import json_normalize
import pandas as pd
import json
import requests as r

# %% [markdown]
# There is great documentation on Kiva's API [here](http://build.kiva.org/api). The documentation explains what parameters (conditions) we need to pass in our request to Kiva's database in order to get the data we want.
#
# We are trying to retrive all Kiva data from Kenya. So we will be using two main parameters where we set country_code=KE (KE is the two letter [ISO](https://en.wikipedia.org/wiki/ISO_3166-2) code for Kenya), and we increase the results per page to 500 (this is the maximum KIVAs API appears to allow). You can see the HTML results of the api call by pasting the url below into your browser, HTML is a format that is really easy to read.
#
# http://api.kivaws.org/v1/loans/search/?country_code=KE&per_page=500
#
# 1) Go ahead and play with the url in order to retrieve different data. For example, how would you retrieve data from South Africa (ZA)?
#
# 2) How would you only retrive 200 results?
#
# Answers:
#
# 1) http://api.kivaws.org/v1/loans/search/?country_code=ZA&per_page=500
#
# 2)  http://api.kivaws.org/v1/loans/search/?country_code=ZA&per_page=200

# %% [markdown]
# We want to request this data from the api and store it in a format that is more intuitive to us - a dataframe. Let's get started. The code below retrieves the first 500 results and converts it into a pandas dataframe. You will get to know a lot more about dataframes over the next few classes.

# %%
d = r.get('http://api.kivaws.org/v1/loans/search.json?country_code=KE&per_page=500')

# %% [markdown]
# Notice that in the request above we specify json as the type of text we want returned. This is easier to handle and change into a python dataframe. You can past the link into your browser to understand the difference between [JSON](https://en.wikipedia.org/wiki/JSON) and [HTML](https://en.wikipedia.org/wiki/HTML).

# %% [markdown]
# By running d.headers below we can see all the data associated with our request. It shows the time of our request, the fact that we are requesting json text 'Content-Type': 'application/json; charset=UTF-8', in addition to other details.

# %%
d.headers
# Out:
# {'Date': 'Tue, 02 May 2017 17:31:33 GMT', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Access-Control-Allow-Origin': '*', 'Expires': 'Tue, 03 Jul 2001 06:00:00 GMT', 'Last-Modified': 'Tue, 02 May 2017 17:31:33 GMT', 'Cache-Control': 'private, no-store, no-cache, must-revalidate, max-age=0, post-check=0, pre-check=0, proxy-revalidate, no-transform', 'Pragma': 'no-cache', 'X-RateLimit-Overall-Limit': '60', 'X-RateLimit-Overall-Remaining': '60', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '27083', 'Content-Type': 'application/json; charset=UTF-8'}

# %% [markdown]
# By running the command d.json() below we can get an idea of what our data looks like before we change it into a pandas data frame.

# %%
d.json()
# Out:
# {'loans': [{'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1286455,
#    'image': {'id': 2509135, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 50,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Caroline',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T17:10:06Z',
#    'posted_date': '2017-05-02T17:10:07Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy an eco-friendly stove.'},
#   {'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1286461,
#    'image': {'id': 2509143, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 50,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Molo'},
#    'name': 'Naomi',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T17:10:07Z',
#    'posted_date': '2017-05-02T17:10:07Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy an eco-friendly stove.'},
#   {'activity': 'Home Energy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286449,
#    'image': {'id': 2509125, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Rodah',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T17:00:05Z',
#    'posted_date': '2017-05-02T17:00:05Z',
#    'sector': 'Personal Use',
#    'status': 'fundraising',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Dairy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286433,
#    'image': {'id': 2509097, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 250,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Iten'},
#    'name': 'Jeniffer',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T16:30:06Z',
#    'posted_date': '2017-05-02T16:30:06Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Animals'}, {'name': '#Biz Durable Asset'}],
#    'use': 'to buy another dairy cow to increase her daily milk collection.'},
#   {'activity': 'Hotel',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286403,
#    'image': {'id': 2509062, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Iten'},
#    'name': 'Hillary',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T15:50:08Z',
#    'posted_date': '2017-05-02T15:50:08Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [],
#    'use': 'to buy wheat flour to make sumptuous dishes for his clients.'},
#   {'activity': 'Home Energy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286416,
#    'image': {'id': 2509083, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Spinicah',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T15:50:08Z',
#    'posted_date': '2017-05-02T15:50:08Z',
#    'sector': 'Personal Use',
#    'status': 'fundraising',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 75,
#    'id': 1286406,
#    'image': {'id': 2509070, 'template_id': 1},
#    'lender_count': 3,
#    'loan_amount': 75,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Molo'},
#    'name': 'Veronica',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T15:40:05Z',
#    'posted_date': '2017-05-02T15:40:05Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Home Energy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286392,
#    'image': {'id': 2509052, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Jackline',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T15:30:05Z',
#    'posted_date': '2017-05-02T15:30:05Z',
#    'sector': 'Personal Use',
#    'status': 'fundraising',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to purchase a solar lantern.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286364,
#    'image': {'id': 2509009, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 250,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Muhoroni'},
#    'name': 'Philles',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T14:20:05Z',
#    'posted_date': '2017-05-02T14:20:05Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Widowed'},
#     {'name': '#Elderly'}],
#    'use': 'to add stock of cooking oil and bread to serve her clients better.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1286339,
#    'image': {'id': 2508983, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 350,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Muhoroni'},
#    'name': 'Anaa',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T13:30:06Z',
#    'posted_date': '2017-05-02T13:30:06Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Widowed'}],
#    'use': 'to buy detergents, spices and rice to grow her kiosk business.'},
#   {'activity': 'Animal Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286310,
#    'image': {'id': 2508944, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.1 34.75', 'type': 'point'},
#     'town': 'Kisumu'},
#    'name': 'Michael',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T13:10:05Z',
#    'posted_date': '2017-05-02T13:10:06Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Animals'}],
#    'use': 'to buy more cows and goats for selling to his clients.'},
#   {'activity': 'Grocery Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286318,
#    'image': {'id': 2508957, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Muhoroni'},
#    'name': 'Eunice',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T13:10:06Z',
#    'posted_date': '2017-05-02T13:10:06Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [],
#    'use': 'to buy more tomatoes and onions to grow her business capital.'},
#   {'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 75,
#    'id': 1286265,
#    'image': {'id': 2508879, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 75,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Esther',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T12:20:05Z',
#    'posted_date': '2017-05-02T12:20:05Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 75,
#    'id': 1286260,
#    'image': {'id': 2508870, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 75,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Mercyline',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T12:10:05Z',
#    'posted_date': '2017-05-02T12:10:05Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1286254,
#    'image': {'id': 2508859, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 50,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kenyenya'},
#    'name': 'Grace',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T11:50:06Z',
#    'posted_date': '2017-05-02T11:50:06Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [{'name': '#Eco-friendly'}, {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Home Energy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1286250,
#    'image': {'id': 2508850, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 50,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Limuru'},
#    'name': 'Mary',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T11:20:06Z',
#    'posted_date': '2017-05-02T11:20:06Z',
#    'sector': 'Personal Use',
#    'status': 'funded',
#    'tags': [{'name': 'volunteer_like'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern.'},
#   {'activity': 'Home Energy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1286246,
#    'image': {'id': 2508847, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 275,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Nkubu'},
#    'name': 'Rose',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T11:10:06Z',
#    'posted_date': '2017-05-02T11:10:06Z',
#    'sector': 'Personal Use',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Earth Day Campaign'],
#    'use': 'to buy a solar lantern and a solar-powered television.'},
#   {'activity': 'Furniture Making',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 375,
#    'id': 1285810,
#    'image': {'id': 2508245, 'template_id': 1},
#    'lender_count': 14,
#    'loan_amount': 775,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.283333 34.75', 'type': 'point'},
#     'town': 'Kakamega'},
#    'name': 'Josphat',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-06-01T04:40:03Z',
#    'posted_date': '2017-05-02T04:40:03Z',
#    'sector': 'Manufacturing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Repeat Borrower'}],
#    'use': 'to buy timber for making furniture.'},
#   {'activity': 'Motorcycle Repair',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285870,
#    'image': {'id': 2508329, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 700,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.283333 34.75', 'type': 'point'},
#     'town': 'Kakamega'},
#    'name': 'Felix',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T02:50:05Z',
#    'posted_date': '2017-05-02T02:50:05Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [],
#    'use': 'for buying more quality tools to service motorbikes for his clients faster.'},
#   {'activity': 'Water Distribution',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 500,
#    'id': 1285766,
#    'image': {'id': 2508190, 'template_id': 1},
#    'lender_count': 20,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Likoni'},
#    'name': 'Khadija',
#    'partner_id': 164,
#    'planned_expiration_date': '2017-06-01T02:00:05Z',
#    'posted_date': '2017-05-02T02:00:05Z',
#    'sector': 'Services',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Parent'}],
#    'use': 'to purchase a water tank and materials for making mats.'},
#   {'activity': 'Fruits & Vegetables',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 450,
#    'id': 1285888,
#    'image': {'id': 2508356, 'template_id': 1},
#    'lender_count': 18,
#    'loan_amount': 450,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.1 34.75', 'type': 'point'},
#     'town': 'Kisumu'},
#    'name': 'Trezer',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T00:20:09Z',
#    'posted_date': '2017-05-02T00:20:09Z',
#    'sector': 'Food',
#    'status': 'funded',
#    'tags': [],
#    'use': 'to add stock of tomatoes, mangoes and avocados to sell and grow her business.'},
#   {'activity': 'Poultry',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1285809,
#    'image': {'id': 2508243, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Emily',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-06-01T00:20:08Z',
#    'posted_date': '2017-05-02T00:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy poultry.'},
#   {'activity': 'Motorcycle Transport',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285876,
#    'image': {'id': 2508340, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.283333 34.75', 'type': 'point'},
#     'town': 'Kakamega'},
#    'name': 'Benjamin',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T00:10:04Z',
#    'posted_date': '2017-05-02T00:10:04Z',
#    'sector': 'Transportation',
#    'status': 'fundraising',
#    'tags': [{'name': '#Biz Durable Asset'}],
#    'use': 'to buy another motorbike to grow his business.'},
#   {'activity': 'Beauty Salon',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1285808,
#    'image': {'id': 2508242, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-4.05 39.666667', 'type': 'point'},
#     'town': 'Mombasa'},
#    'name': 'Emily',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-06-01T00:00:05Z',
#    'posted_date': '2017-05-02T00:00:05Z',
#    'sector': 'Services',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'}],
#    'use': 'to buy more cosmetics, hair food and sprays to serve her clients.'},
#   {'activity': 'Milk Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1285825,
#    'image': {'id': 2506870, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.283333 36.066667', 'type': 'point'},
#     'town': 'Nakuru'},
#    'name': 'Irine',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-31T23:50:04Z',
#    'posted_date': '2017-05-01T23:50:04Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'use': 'to purchase more stock of milk for sale.'},
#   {'activity': 'Poultry',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1285860,
#    'image': {'id': 2508307, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Judy',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T23:40:05Z',
#    'posted_date': '2017-05-01T23:40:05Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to start poultry farming.'},
#   {'activity': 'Motorcycle Transport',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285859,
#    'image': {'id': 2508305, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.283333 34.75', 'type': 'point'},
#     'town': 'Kakamega'},
#    'name': 'Paul',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-05-31T23:30:03Z',
#    'posted_date': '2017-05-01T23:30:03Z',
#    'sector': 'Transportation',
#    'status': 'fundraising',
#    'tags': [{'name': '#Biz Durable Asset'}],
#    'use': 'to buy another motorbike to grow his business.'},
#   {'activity': 'Clothing Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285843,
#    'image': {'id': 2508289, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-1.516667 37.266667', 'type': 'point'},
#     'town': 'Machakos'},
#    'name': 'Salome',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-05-31T22:40:03Z',
#    'posted_date': '2017-05-01T22:40:03Z',
#    'sector': 'Clothing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}],
#    'use': 'to buy more clothes to grow her business and serve clients better.'},
#   {'activity': 'Motorcycle Transport',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285790,
#    'image': {'id': 2508217, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 36.866667', 'type': 'point'},
#     'town': 'Narok'},
#    'name': 'Benard',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-05-31T22:20:03Z',
#    'posted_date': '2017-05-01T22:20:03Z',
#    'sector': 'Transportation',
#    'status': 'fundraising',
#    'tags': [{'name': '#Biz Durable Asset'}],
#    'use': 'to buy another motorbike to grow his business.'},
#   {'activity': 'Motorcycle Transport',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285830,
#    'image': {'id': 2508273, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.283333 34.75', 'type': 'point'},
#     'town': 'Kakamega'},
#    'name': 'Daniel',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-05-31T22:20:03Z',
#    'posted_date': '2017-05-01T22:20:03Z',
#    'sector': 'Transportation',
#    'status': 'fundraising',
#    'tags': [{'name': '#Biz Durable Asset'}],
#    'use': 'to buy another motorbike to grow his business.'},
#   {'activity': 'Fruits & Vegetables',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285836,
#    'image': {'id': 2508282, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Flomena',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T22:20:02Z',
#    'posted_date': '2017-05-01T22:20:02Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fruits and vegetables and start a new grocery store.'},
#   {'activity': 'Poultry',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1285837,
#    'image': {'id': 2508283, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Emmy',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T22:20:02Z',
#    'posted_date': '2017-05-01T22:20:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy chicks and construct new hatcheries.'},
#   {'activity': 'Dairy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285826,
#    'image': {'id': 2508267, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Limuru'},
#    'name': 'Hannah',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T22:10:03Z',
#    'posted_date': '2017-05-01T22:10:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy animal feeds.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1285834,
#    'image': {'id': 2508279, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Limuru'},
#    'name': 'Leah',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T22:10:03Z',
#    'posted_date': '2017-05-01T22:10:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy good-quality seeds and fertilizer for her farm.'},
#   {'activity': 'Furniture Making',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 225,
#    'id': 1285801,
#    'image': {'id': 2508233, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 36.866667', 'type': 'point'},
#     'town': 'Narok'},
#    'name': 'Lenald',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-05-31T22:00:03Z',
#    'posted_date': '2017-05-01T22:00:03Z',
#    'sector': 'Manufacturing',
#    'status': 'fundraising',
#    'tags': [],
#    'use': 'to add more timber and nails to grow his carpentry business.'},
#   {'activity': 'Pharmacy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1285823,
#    'image': {'id': 2506650, 'template_id': 1},
#    'lender_count': 12,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.05 35.716667', 'type': 'point'},
#     'town': 'ELDAMA RAVINE'},
#    'name': 'Stanley',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-31T22:00:02Z',
#    'posted_date': '2017-05-01T22:00:03Z',
#    'sector': 'Health',
#    'status': 'funded',
#    'tags': [{'name': '#Health and Sanitation'}],
#    'use': 'to buy more stock of medicines such as Panadol, brufen and action mara mojo to sell.'},
#   {'activity': 'Shoe Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1285822,
#    'image': {'id': 2508261, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 375,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-1.516667 37.266667', 'type': 'point'},
#     'town': 'Machakos'},
#    'name': 'Sahara',
#    'partner_id': 386,
#    'planned_expiration_date': '2017-05-31T21:50:05Z',
#    'posted_date': '2017-05-01T21:50:05Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'use': 'to increase her stock of shoes and clothes to boost her boutique business.'},
#   {'activity': 'Poultry',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1285796,
#    'image': {'id': 2508224, 'template_id': 1},
#    'lender_count': 7,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Marselah',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T21:50:04Z',
#    'posted_date': '2017-05-01T21:50:04Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy different breeds of poultry.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1285812,
#    'image': {'id': 2508248, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.1 34.75', 'type': 'point'},
#     'town': 'Kisumu'},
#    'name': 'Millicent',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-31T21:50:03Z',
#    'posted_date': '2017-05-01T21:50:04Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'use': 'to buy more stock of clothes.'},
#   {'activity': 'Poultry',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 400,
#    'id': 1285814,
#    'image': {'id': 2508250, 'template_id': 1},
#    'lender_count': 14,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Caroline',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T21:50:04Z',
#    'posted_date': '2017-05-01T21:50:04Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': 'volunteer_like'}, {'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy different breeds of poultry.'},
#   {'activity': 'Primary/secondary school costs',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 600,
#    'id': 1285792,
#    'image': {'id': 2501903, 'template_id': 1},
#    'lender_count': 18,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kapsabet'},
#    'name': 'Pilista',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-31T21:50:02Z',
#    'posted_date': '2017-05-01T21:50:02Z',
#    'sector': 'Education',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Elderly'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to pay school fees for her children.'},
#   {'activity': 'Dairy',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285793,
#    'image': {'id': 2508222, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Limuru'},
#    'name': 'Irene',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T21:10:02Z',
#    'posted_date': '2017-05-01T21:10:02Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Animals'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy animal feeds.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285784,
#    'image': {'id': 2508214, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Zeddy',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T21:00:03Z',
#    'posted_date': '2017-05-01T21:00:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fertilizer, pesticides and herbicides.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285756,
#    'image': {'id': 2508174, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Josphine',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T20:40:03Z',
#    'posted_date': '2017-05-01T20:40:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Biz Durable Asset'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm tools and equipment.'},
#   {'activity': 'Retail',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285762,
#    'image': {'id': 2508184, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 775,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.1 34.75', 'type': 'point'},
#     'town': 'Kisumu'},
#    'name': 'Macrine',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-31T20:40:02Z',
#    'posted_date': '2017-05-01T20:40:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Parent'}],
#    'use': 'to buy more stocks of fish.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 125,
#    'id': 1285751,
#    'image': {'id': 2508167, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Ruth',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-31T20:30:03Z',
#    'posted_date': '2017-05-01T20:30:03Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs.'},
#   {'activity': 'Clothing Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285755,
#    'image': {'id': 2508172, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Likoni'},
#    'name': 'Mary',
#    'partner_id': 164,
#    'planned_expiration_date': '2017-05-31T20:30:03Z',
#    'posted_date': '2017-05-01T20:30:03Z',
#    'sector': 'Clothing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Parent'}],
#    'use': 'to purchase three bales of clothes to resell.'},
#   {'activity': 'Food Stall',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285744,
#    'image': {'id': 2508159, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Likoni'},
#    'name': 'Khadija',
#    'partner_id': 164,
#    'planned_expiration_date': '2017-05-31T20:20:04Z',
#    'posted_date': '2017-05-01T20:20:04Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'use': 'to purchase bundles of wheat flour, maize flour and cooking-fat oil.'},
#   {'activity': 'Charcoal Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285738,
#    'image': {'id': 2508150, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Likoni'},
#    'name': 'Mwanamwinyi',
#    'partner_id': 164,
#    'planned_expiration_date': '2017-05-31T20:10:03Z',
#    'posted_date': '2017-05-01T20:10:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Parent'}],
#    'use': 'to buy charcoal.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285727,
#    'image': {'id': 2508029, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.1 34.75', 'type': 'point'},
#     'town': 'Kisumu'},
#    'name': 'Judith',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-31T20:00:04Z',
#    'posted_date': '2017-05-01T20:00:04Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy sugar, bread, flour, rice, soap, and other items for her store.'},
#   {'activity': 'Clothing Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1285728,
#    'image': {'id': 2508139, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Likoni'},
#    'name': 'Agnes',
#    'partner_id': 164,
#    'planned_expiration_date': '2017-05-31T19:50:02Z',
#    'posted_date': '2017-05-01T19:50:02Z',
#    'sector': 'Clothing',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'use': 'to purchase  clothes for resale.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 9,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281837,
#    'image': {'id': 2411491, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 475,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Chwele'},
#    'name': "Christine's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase solar lights and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 16,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282213,
#    'image': {'id': 2377388, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 1400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Teso'},
#    'name': "Francis' Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Elderly'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase solar lights and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 16,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282223,
#    'image': {'id': 2377391, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 1075,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Teso'},
#    'name': "Fredrick's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase a solar light and improve maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 16,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282227,
#    'image': {'id': 2377398, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 1300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Teso'},
#    'name': "Joseph's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase a solar light and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 7,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282242,
#    'image': {'id': 2381483, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 400,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Teso'},
#    'name': "Margaret's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase a solar light and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 9,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282248,
#    'image': {'id': 2381479, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 650,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Teso'},
#    'name': "Penina's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': 'volunteer_pick'},
#     {'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase a solar light and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 9,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282256,
#    'image': {'id': 2414592, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 600,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Matete'},
#    'name': "Christine's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'purchase solar lights and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 8,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1282265,
#    'image': {'id': 2381489, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 475,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Teso'},
#    'name': "Pamela's Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:08Z',
#    'posted_date': '2017-05-01T18:20:08Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase a solar light and increase maize cultivation.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 10,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281779,
#    'image': {'id': 2415740, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 475,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.616667 34.766667', 'type': 'point'},
#     'town': 'Webuye'},
#    'name': "Phylis' Group",
#    'partner_id': 202,
#    'planned_expiration_date': '2017-05-31T18:20:07Z',
#    'posted_date': '2017-05-01T18:20:07Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Sustainable Ag'},
#     {'name': '#Eco-friendly'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Technology'}],
#    'themes': ['Green', 'Rural Exclusion', 'Earth Day Campaign'],
#    'use': 'to purchase a solar light and increase cultivation of maize.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 12,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1281783,
#    'image': {'id': 2415763, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 700,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.616667 34.766667', 'type': 'point'},
#     'town': 'Webuye'},
# ...
#    'loan_amount': 725,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Matuu'},
#    'name': 'Daniel',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-25T14:50:03Z',
#    'posted_date': '2017-04-25T14:50:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}, {'name': '#Repeat Borrower'}],
#    'use': 'to buy stock like cups, plates, spoons, plastic basins, etc., for selling.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1279465,
#    'image': {'id': 2178807, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-1.516667 37.266667', 'type': 'point'},
#     'town': 'Machakos'},
#    'name': 'Agnes',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-25T12:40:02Z',
#    'posted_date': '2017-04-25T12:40:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy stock of sodas, flour, milk, rice, paraffin, body lotions, cooking oil, cereals, detergents, sugar, bread, etc.'},
#   {'activity': 'Fruits & Vegetables',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1279466,
#    'image': {'id': 2499206, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Maria',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-25T12:40:02Z',
#    'posted_date': '2017-04-25T12:40:02Z',
#    'sector': 'Food',
#    'status': 'funded',
#    'tags': [{'name': '#First Loan'},
#     {'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'}],
#    'use': 'to buy bananas, mangoes, avocados, etc for selling.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 300,
#    'id': 1278426,
#    'image': {'id': 2498281, 'template_id': 1},
#    'lender_count': 5,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kericho'},
#    'name': 'Sharon',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-25T12:10:02Z',
#    'posted_date': '2017-04-25T12:10:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy seeds and fertilizers and expand her horticultural enterprise.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1278855,
#    'image': {'id': 2498917, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Pamela',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-25T06:30:08Z',
#    'posted_date': '2017-04-25T06:30:09Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy improved seeds, fertilizers and other farm inputs that control weeds and pests.'},
#   {'activity': 'Farming',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1278406,
#    'image': {'id': 2498248, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1.016667 35', 'type': 'point'},
#     'town': 'Kitale'},
#    'name': 'Gaudencian',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-24T23:20:03Z',
#    'posted_date': '2017-04-24T23:20:04Z',
#    'sector': 'Agriculture',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy fertilizers, pesticides and herbicides.'},
#   {'activity': 'Fuel/Firewood',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 25,
#    'id': 1278749,
#    'image': {'id': 2486369, 'template_id': 1},
#    'lender_count': 1,
#    'loan_amount': 300,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Evans',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T22:20:02Z',
#    'posted_date': '2017-04-24T22:20:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Parent'}],
#    'use': 'to purchase more trees to make firewood to sell with an ambition of buying a new power saw in order to harvest more trees.'},
#   {'activity': 'Farming',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1278746,
#    'image': {'id': 2498786, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Kericho'},
#    'name': 'Joyce',
#    'partner_id': 156,
#    'planned_expiration_date': '2017-05-24T22:10:03Z',
#    'posted_date': '2017-04-24T22:10:03Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Parent'}],
#    'themes': ['Rural Exclusion'],
#    'use': 'to buy farm inputs such as seeds to enable her to grow more vegetables.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1279038,
#    'image': {'id': 2493781, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 700,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Matuu'},
#    'name': 'Annah',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:50:02Z',
#    'posted_date': '2017-04-24T21:50:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy stock of sugar, tea leaves, milk, bread, paraffin, body lotions, detergents, etc.'},
#   {'activity': 'Fruits & Vegetables',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1279039,
#    'image': {'id': 2493776, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 50,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Annette',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:50:02Z',
#    'posted_date': '2017-04-24T21:50:02Z',
#    'sector': 'Food',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'}],
#    'use': 'to buy stock of bananas and oranges for selling.'},
#   {'activity': 'Cereals',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 0,
#    'id': 1279017,
#    'image': {'id': 2499087, 'template_id': 1},
#    'lender_count': 0,
#    'loan_amount': 500,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Maua'},
#    'name': 'Charity',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-24T21:40:03Z',
#    'posted_date': '2017-04-24T21:40:03Z',
#    'sector': 'Food',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Vegan'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy more stock of cereals.'},
#   {'activity': 'Cosmetics Sales',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1279035,
#    'image': {'id': 2495329, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 450,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-1.516667 37.266667', 'type': 'point'},
#     'town': 'Machakos'},
#    'name': 'Diana',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:02Z',
#    'posted_date': '2017-04-24T21:40:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'},
#     {'name': '#Female Education'}],
#    'use': 'to buy stock of hair and body lotions, toothpaste, body sprays, nail polish, lipstick, etc.'},
#   {'activity': 'Movie Tapes & DVDs',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1279036,
#    'image': {'id': 2495330, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Samuel',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:03Z',
#    'posted_date': '2017-04-24T21:40:03Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#First Loan'}, {'name': '#Parent'}],
#    'use': 'to buy stock of movie and music DVDs to resell.'},
#   {'activity': 'Clothing Sales',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1279037,
#    'image': {'id': 2493759, 'template_id': 1},
#    'lender_count': 6,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Agnes',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:03Z',
#    'posted_date': '2017-04-24T21:40:03Z',
#    'sector': 'Clothing',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'}, {'name': '#Repeat Borrower'}],
#    'use': "to buy a large stock of clothes to meet her customers' demand."},
#   {'activity': 'Dairy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1279016,
#    'image': {'id': 2491377, 'template_id': 1},
#    'lender_count': 4,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Daisy',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:02Z',
#    'posted_date': '2017-04-24T21:40:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Animals'},
#     {'name': '#Parent'},
#     {'name': '#Biz Durable Asset'}],
#    'use': 'to purchase milking materials in hopes this will help her buy another dairy cow.'},
#   {'activity': 'Livestock',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 75,
#    'id': 1279031,
#    'image': {'id': 2495366, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 75,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Wayua',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:02Z',
#    'posted_date': '2017-04-24T21:40:02Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Animals'},
#     {'name': '#Elderly'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy animal feeds for the goats and seeds and fertilizers for the farm.'},
#   {'activity': 'General Store',
#    'basket_amount': 0,
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 50,
#    'id': 1279032,
#    'image': {'id': 2495324, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 450,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Matuu'},
#    'name': 'Judith',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:02Z',
#    'posted_date': '2017-04-24T21:40:02Z',
#    'sector': 'Retail',
#    'status': 'fundraising',
#    'tags': [{'name': '#Woman Owned Biz'},
#     {'name': '#Elderly'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'},
#     {'name': '#Repeat Borrower'}],
#    'use': 'to buy stock of detergent, sugar, bread, milk, rice, sodas, cereals, etc.'},
#   {'activity': 'Food',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 100,
#    'id': 1279034,
#    'image': {'id': 2495371, 'template_id': 1},
#    'lender_count': 3,
#    'loan_amount': 100,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '1 38', 'type': 'point'},
#     'town': 'Tala;Kangundo'},
#    'name': 'Benjamin',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:40:02Z',
#    'posted_date': '2017-04-24T21:40:02Z',
#    'sector': 'Food',
#    'status': 'funded',
#    'tags': [{'name': 'user_favorite'},
#     {'name': '#Parent'},
#     {'name': '#Schooling'}],
#    'use': "to buy large supplies of bread to meet his customers' demands and increase his profits."},
#   {'activity': 'General Store',
#    'bonus_credit_eligibility': True,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 200,
#    'id': 1279024,
#    'image': {'id': 2499093, 'template_id': 1},
#    'lender_count': 8,
#    'loan_amount': 200,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '-0.716667 36.433333', 'type': 'point'},
#     'town': 'Naivasha'},
#    'name': 'John',
#    'partner_id': 138,
#    'planned_expiration_date': '2017-05-24T21:30:06Z',
#    'posted_date': '2017-04-24T21:30:06Z',
#    'sector': 'Retail',
#    'status': 'funded',
#    'tags': [{'name': 'volunteer_pick'}, {'name': '#Parent'}],
#    'use': 'to buy additional fruits and vegetables.'},
#   {'activity': 'Dairy',
#    'bonus_credit_eligibility': False,
#    'borrower_count': 1,
#    'description': {'languages': ['en']},
#    'funded_amount': 150,
#    'id': 1279018,
#    'image': {'id': 2491379, 'template_id': 1},
#    'lender_count': 2,
#    'loan_amount': 150,
#    'location': {'country': 'Kenya',
#     'country_code': 'KE',
#     'geo': {'level': 'town', 'pairs': '0.516667 35.283333', 'type': 'point'},
#     'town': 'Eldoret'},
#    'name': 'Grace',
#    'partner_id': 133,
#    'planned_expiration_date': '2017-05-24T21:30:04Z',
#    'posted_date': '2017-04-24T21:30:05Z',
#    'sector': 'Agriculture',
#    'status': 'funded',
#    'tags': [{'name': '#Elderly'}],
#    'use': 'to purchase seeds used to plant nappier grass for the animals to help her provide basic needs, e.g., food, clothing, and medical coverage for her kids.'}],
#  'paging': {'page': 1, 'page_size': 500, 'pages': 255, 'total': 127383}}

# %%
data = json.loads(d.text)

# %%
loans=json_normalize(data['loans'])

# %%
loans.head(3)
# Out:
#       activity  basket_amount bonus_credit_eligibility  borrower_count  \
# 0  Home Energy            NaN                    False               1
# 1  Home Energy            NaN                    False               1
# 2  Home Energy            0.0                    False               1
#
#   description.languages  funded_amount       id  image.id  image.template_id  \
# 0                  [en]             50  1286455   2509135                  1
# 1                  [en]             50  1286461   2509143                  1
# 2                  [en]              0  1286449   2509125                  1
#
#    lender_count              ...                location.town      name  \
# 0             1              ...                       Kitale  Caroline
# 1             2              ...                         Molo     Naomi
# 2             0              ...                     Kenyenya     Rodah
#
#   partner_id planned_expiration_date           posted_date        sector  \
# 0        156    2017-06-01T17:10:06Z  2017-05-02T17:10:07Z  Personal Use
# 1        156    2017-06-01T17:10:07Z  2017-05-02T17:10:07Z  Personal Use
# 2        156    2017-06-01T17:00:05Z  2017-05-02T17:00:05Z  Personal Use
#
#         status                                               tags  \
# 0       funded                                                 []
# 1       funded                                                 []
# 2  fundraising  [{'name': '#Eco-friendly'}, {'name': '#Technol...
#
#                         themes                            use
# 0  [Green, Earth Day Campaign]  to buy an eco-friendly stove.
# 1  [Green, Earth Day Campaign]  to buy an eco-friendly stove.
# 2  [Green, Earth Day Campaign]        to buy a solar lantern.
#
# [3 rows x 26 columns]

# %% [markdown]
# We have now extracted the first 500 rows of loans from the API. Now, we need to extract this data more systematically for all Kenyan loan results. KIVA has a parameter called page but does not allow for range of pages, so we will have to create a python loop to go through each page of results and add to our dataset.

# %%
, country_iso_code, dataset

# %%
def extract_data(pages):
    while in range
