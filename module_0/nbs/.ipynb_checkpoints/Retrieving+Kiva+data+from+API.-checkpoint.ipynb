# %% [markdown]
# # Retrieving data from Kiva API

# %% [markdown]
# We will be using [KIVA](https://www.kiva.org/) data for the entirety of this course. Kiva makes it's data publically available through it's [API](http://build.kiva.org/).
#
# Not sure what an API is? It stands for Application Program Interface. Code Academy has a fantastic short course (link [here](https://www.codecademy.com/en/tracks/placekitten) that introduces you to APIs and allows you to pull images of kittens from a website by the end of the session.
#
# Below, we import the packages we need in order to retrieve data from the API.

# %%
from urllib.request import urlopen, Request
import json
from pandas.io.json import json_normalize
import pandas as pd
import json
import requests as r

# %% [markdown]
# There is great documentation on Kiva's API [here](http://build.kiva.org/api). The documentation explains what parameters (conditions) we need to pass in our request to Kiva's database in order to get the data we want.
#
# We are trying to retrive all Kiva data from Kenya. So we will be using two main parameters where we set country_code=KE (KE is the two letter [ISO](https://en.wikipedia.org/wiki/ISO_3166-2) code for Kenya), and we increase the results per page to 500 (this is the maximum KIVAs API appears to allow). You can see the HTML results of the api call by pasting the url below into your browser, HTML is a format that is really easy to read.
#
# http://api.kivaws.org/v1/loans/search/?country_code=KE&per_page=500
#
# 1) Go ahead and play with the url in order to retrieve different data. For example, how would you retrieve data from South Africa (ZA)?
#
# 2) How would you only retrive 200 results?
#
# Answers:
#
# 1) http://api.kivaws.org/v1/loans/search/?country_code=ZA&per_page=500
#
# 2)  http://api.kivaws.org/v1/loans/search/?country_code=ZA&per_page=200

# %% [markdown]
# We want to request this data from the api and store it in a format that is more intuitive to us - a dataframe. Let's get started. The code below retrieves the first 500 results and converts it into a pandas dataframe. You will get to know a lot more about dataframes over the next few classes.

# %%
d = r.get('http://api.kivaws.org/v1/loans/search.json?country_code=KE&per_page=500')

# %% [markdown]
# Notice that in the request above we specify json as the type of text we want returned. This is easier to handle and change into a python dataframe. You can past the link into your browser to understand the difference between [JSON](https://en.wikipedia.org/wiki/JSON) and [HTML](https://en.wikipedia.org/wiki/HTML).

# %% [markdown]
# By running d.headers below we can see all the data associated with our request. It shows the time of our request, the fact tha

# %%
d.headers
# Out:
# {'Date': 'Tue, 02 May 2017 17:31:33 GMT', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Access-Control-Allow-Origin': '*', 'Expires': 'Tue, 03 Jul 2001 06:00:00 GMT', 'Last-Modified': 'Tue, 02 May 2017 17:31:33 GMT', 'Cache-Control': 'private, no-store, no-cache, must-revalidate, max-age=0, post-check=0, pre-check=0, proxy-revalidate, no-transform', 'Pragma': 'no-cache', 'X-RateLimit-Overall-Limit': '60', 'X-RateLimit-Overall-Remaining': '60', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '27083', 'Content-Type': 'application/json; charset=UTF-8'}

# %% [markdown]
# By running the command d.json() below we can get an idea of what our data looks like before we change it into a pandas data frame.

# %%
d.json()
# Out:
# {u'loans': [{u'activity': u'Shoe Sales',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284698,
#    u'image': {u'id': 2506885, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 100,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Gatundu'},
#    u'name': u'Moses',
#    u'partner_id': 388,
#    u'planned_expiration_date': u'2017-05-30T19:00:04Z',
#    u'posted_date': u'2017-04-30T19:00:04Z',
#    u'sector': u'Retail',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}, {u'name': u'#Schooling'}],
#    u'use': u"to buy more shoes for resale to meet customers' demands and increase his income to pay his child's school fees and clothe his family."},
#   {u'activity': u'Food Stall',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284709,
#    u'image': {u'id': 2506922, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 925,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kawangware'},
#    u'name': u'Francis Muchiri',
#    u'partner_id': 262,
#    u'planned_expiration_date': u'2017-05-30T19:00:04Z',
#    u'posted_date': u'2017-04-30T19:00:04Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Youth'],
#    u'use': u'to purchase a new grill and expand his business.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284713,
#    u'image': {u'id': 2506925, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 250,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.566667 34.566667',
#      u'type': u'point'},
#     u'town': u'Bungoma'},
#    u'name': u'Jedidah',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T19:00:03Z',
#    u'posted_date': u'2017-04-30T19:00:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Elderly'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy good-quality seeds and fertilizer for her farm.'},
#   {u'activity': u'Dairy',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 2,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284697,
#    u'image': {u'id': 2506733, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Gatundu'},
#    u'name': u'Kariminu Good Luck Y. Mothers Group',
#    u'partner_id': 388,
#    u'planned_expiration_date': u'2017-05-30T18:40:04Z',
#    u'posted_date': u'2017-04-30T18:40:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Animals'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'}],
#    u'use': u'to buy a dairy cow for increased milk production, hence increased income to pay school fees for her children.'},
#   {u'activity': u'Carpentry',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284699,
#    u'image': {u'id': 2506592, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 100,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Gatundu'},
#    u'name': u'Joseph',
#    u'partner_id': 388,
#    u'planned_expiration_date': u'2017-05-30T18:40:04Z',
#    u'posted_date': u'2017-04-30T18:40:04Z',
#    u'sector': u'Construction',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Elderly'}, {u'name': u'#Schooling'}],
#    u'use': u"to buy more timber for increased production and meeting his customers' demands, hence increasing his income to pay school fees for his children."},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284693,
#    u'image': {u'id': 2506888, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 450,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Mary',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:40:03Z',
#    u'posted_date': u'2017-04-30T18:40:03Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals to sell at her local market.'},
#   {u'activity': u'Construction Supplies',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284689,
#    u'image': {u'id': 2506765, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 100,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Gatundu'},
#    u'name': u'David',
#    u'partner_id': 388,
#    u'planned_expiration_date': u'2017-05-30T18:30:05Z',
#    u'posted_date': u'2017-04-30T18:30:05Z',
#    u'sector': u'Construction',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Elderly'}, {u'name': u'#Schooling'}],
#    u'use': u"to buy cement for resale to meet customers' demands and increase income to provide food for his family and pay school fees for his children."},
#   {u'activity': u'Shoe Sales',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284695,
#    u'image': {u'id': 2506897, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Muranga'},
#    u'name': u'Virginia',
#    u'partner_id': 386,
#    u'planned_expiration_date': u'2017-05-30T18:30:05Z',
#    u'posted_date': u'2017-04-30T18:30:05Z',
#    u'sector': u'Retail',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'use': u'to add stock of shoes and sandals and to buy iron sheets to renovate her selling stand.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 100,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284688,
#    u'image': {u'id': 2506881, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 100,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.566667 34.566667',
#      u'type': u'point'},
#     u'town': u'Bungoma'},
#    u'name': u'Everline',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:30:03Z',
#    u'posted_date': u'2017-04-30T18:30:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs.'},
#   {u'activity': u'Primary/secondary school costs',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284679,
#    u'image': {u'id': 2501909, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 600,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsabet'},
#    u'name': u'Lena',
#    u'partner_id': 133,
#    u'planned_expiration_date': u'2017-05-30T18:20:03Z',
#    u'posted_date': u'2017-04-30T18:20:03Z',
#    u'sector': u'Education',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Schooling'}, {u'name': u'#Repeat Borrower'}],
#    u'use': u'to pay school fees for her children.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284638,
#    u'image': {u'id': 2506778, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Eunice',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:10:02Z',
#    u'posted_date': u'2017-04-30T18:10:03Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy more cereals to sell at her local market.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284639,
#    u'image': {u'id': 2506769, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 500,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Janet',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:10:03Z',
#    u'posted_date': u'2017-04-30T18:10:03Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'volunteer_pick'},
#     {u'name': u'volunteer_like'},
#     {u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals so that she can start selling cereals at her local market and increase her income.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284668,
#    u'image': {u'id': 2506840, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapcherop'},
#    u'name': u'Selly',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:10:03Z',
#    u'posted_date': u'2017-04-30T18:10:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and expand her horticultural farming.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284626,
#    u'image': {u'id': 2506760, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Rael',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:00:05Z',
#    u'posted_date': u'2017-04-30T18:00:05Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy more cereals to sell at her local market.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 25,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284627,
#    u'image': {u'id': 2506764, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Berina',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:00:05Z',
#    u'posted_date': u'2017-04-30T18:00:05Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals to sell at her local market.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284629,
#    u'image': {u'id': 2506766, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Atandi',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T18:00:05Z',
#    u'posted_date': u'2017-04-30T18:00:05Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals and sell at his local market.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284502,
#    u'image': {u'id': 2506583, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsowar'},
#    u'name': u'Nelly',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T17:30:05Z',
#    u'posted_date': u'2017-04-30T17:30:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs such as fertilizer and seeds to enable her to grow more vegetables.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284520,
#    u'image': {u'id': 2506604, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyahururu'},
#    u'name': u'Peris',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T17:20:04Z',
#    u'posted_date': u'2017-04-30T17:20:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs.'},
#   {u'activity': u'Agriculture',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284489,
#    u'image': {u'id': 2506569, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Susan',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T17:10:05Z',
#    u'posted_date': u'2017-04-30T17:10:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Job Creator'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs and pay for hired labor.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284486,
#    u'image': {u'id': 2506567, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Monica',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T17:00:05Z',
#    u'posted_date': u'2017-04-30T17:00:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs.'},
#   {u'activity': u'Agriculture',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284488,
#    u'image': {u'id': 2506568, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 125,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Shadrack',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T17:00:05Z',
#    u'posted_date': u'2017-04-30T17:00:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs, (fertilizers, pesticides and herbicides).'},
#   {u'activity': u'Clothing Sales',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284579,
#    u'image': {u'id': 2503863, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsabet'},
#    u'name': u'Ruth',
#    u'partner_id': 133,
#    u'planned_expiration_date': u'2017-05-30T17:00:02Z',
#    u'posted_date': u'2017-04-30T17:00:02Z',
#    u'sector': u'Clothing',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Eco-friendly'},
#     {u'name': u'#Elderly'}],
#    u'use': u'to purchase bales of clothes to sell to her clients.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284470,
#    u'image': {u'id': 2506545, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Thika'},
#    u'name': u'Jane',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T16:20:08Z',
#    u'posted_date': u'2017-04-30T16:20:08Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and expand her horticulture farm.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 25,
#    u'id': 1284435,
#    u'image': {u'id': 2506509, u'template_id': 1},
#    u'lender_count': 1,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Ben',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T16:00:05Z',
#    u'posted_date': u'2017-04-30T16:00:06Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy fertilizers, pesticides and herbicides.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284394,
#    u'image': {u'id': 2506471, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 500,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsowar'},
#    u'name': u'Everlyne',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T16:00:05Z',
#    u'posted_date': u'2017-04-30T16:00:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and start horticulture farming.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284430,
#    u'image': {u'id': 2506505, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Mary',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T16:00:05Z',
#    u'posted_date': u'2017-04-30T16:00:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to start horticultural farming and provide a better income for her six children.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284385,
#    u'image': {u'id': 2506462, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nkubu'},
#    u'name': u'Regina',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T15:50:05Z',
#    u'posted_date': u'2017-04-30T15:50:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Schooling'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs to increase her farming.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284415,
#    u'image': {u'id': 2506490, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Hellen',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T15:50:05Z',
#    u'posted_date': u'2017-04-30T15:50:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Biz Durable Asset'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm tools and equipment.'},
#   {u'activity': u'Primary/secondary school costs',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 150,
#    u'id': 1284416,
#    u'image': {u'id': 2506491, u'template_id': 1},
#    u'lender_count': 4,
#    u'loan_amount': 150,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kericho'},
#    u'name': u'Charles',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T15:50:05Z',
#    u'posted_date': u'2017-04-30T15:50:05Z',
#    u'sector': u'Education',
#    u'status': u'funded',
#    u'tags': [{u'name': u'volunteer_pick'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'}],
#    u'use': u'to pay school fees for his children.'},
#   {u'activity': u'Agriculture',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284379,
#    u'image': {u'id': 2506450, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 600,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Molo'},
#    u'name': u'Sophia',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T15:40:07Z',
#    u'posted_date': u'2017-04-30T15:40:07Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to purchase farm inputs (fertilizers, pesticides and herbicides).'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284406,
#    u'image': {u'id': 2506481, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kerugoya'},
#    u'name': u'Loise',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T15:40:07Z',
#    u'posted_date': u'2017-04-30T15:40:07Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Elderly'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and start horticulture farming.'},
#   {u'activity': u'Farming',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 150,
#    u'id': 1284375,
#    u'image': {u'id': 2506444, u'template_id': 1},
#    u'lender_count': 1,
#    u'loan_amount': 150,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kerugoya'},
#    u'name': u'Hellen',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T15:30:05Z',
#    u'posted_date': u'2017-04-30T15:30:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds to begin her horticulture farming.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284366,
#    u'image': {u'id': 2506430, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Anne',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T14:50:03Z',
#    u'posted_date': u'2017-04-30T14:50:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to purchase farm inputs such as fertilizer and seeds to enable her to grow more vegetables.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284361,
#    u'image': {u'id': 2506425, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsowar'},
#    u'name': u'Alice',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T14:30:06Z',
#    u'posted_date': u'2017-04-30T14:30:06Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and start horticulture farming.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284302,
#    u'image': {u'id': 2506357, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 350,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Florence',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T14:00:06Z',
#    u'posted_date': u'2017-04-30T14:00:06Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Elderly'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs.'},
#   {u'activity': u'Agriculture',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284303,
#    u'image': {u'id': 2506358, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Joan',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T14:00:06Z',
#    u'posted_date': u'2017-04-30T14:00:06Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm tools and equipment for her farming business.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1282400,
#    u'image': {u'id': 2504046, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 600,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kericho'},
#    u'name': u'Betty',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T13:50:07Z',
#    u'posted_date': u'2017-04-30T13:50:07Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Repeat Borrower'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and improve her horticulture farming.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284304,
#    u'image': {u'id': 2506360, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Flora',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T13:50:07Z',
#    u'posted_date': u'2017-04-30T13:50:07Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy new farm tools and equipment.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1284305,
#    u'image': {u'id': 2506363, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Jacklyne',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T13:50:07Z',
#    u'posted_date': u'2017-04-30T13:50:07Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Schooling'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs (fertilizers, pesticides and herbicides).'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1282372,
#    u'image': {u'id': 2504022, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Ann',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T13:10:03Z',
#    u'posted_date': u'2017-04-30T13:10:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and fertilizers and expand her horticultural farm.'},
#   {u'activity': u'Higher education costs',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 700,
#    u'id': 1283742,
#    u'image': {u'id': 2505410, u'template_id': 1},
#    u'lender_count': 23,
#    u'loan_amount': 3375,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'-1.283333 36.816667',
#      u'type': u'point'},
#     u'town': u'Nairobi'},
#    u'name': u'Emma',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T02:20:02Z',
#    u'posted_date': u'2017-04-30T02:20:02Z',
#    u'sector': u'Education',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'},
#     {u'name': u'#Schooling'},
#     {u'name': u'#Female Education'}],
#    u'themes': [u'Higher Education'],
#    u'use': u'to pay for a course in human resource managment.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283578,
#    u'image': {u'id': 2505292, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kericho'},
#    u'name': u'Gladys',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-30T01:30:04Z',
#    u'posted_date': u'2017-04-30T01:30:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds and expand her horticulture farming.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283636,
#    u'image': {u'id': 2505338, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kenyenya'},
#    u'name': u'David',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T23:30:04Z',
#    u'posted_date': u'2017-04-29T23:30:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs such as seed.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283453,
#    u'image': {u'id': 2505213, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Jackline',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T22:30:02Z',
#    u'posted_date': u'2017-04-29T22:30:02Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy fertilizers, pesticides and herbicides.'},
#   {u'activity': u'Poultry',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 200,
#    u'id': 1283555,
#    u'image': {u'id': 2505279, u'template_id': 1},
#    u'lender_count': 5,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kericho'},
#    u'name': u'Rose',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T22:00:03Z',
#    u'posted_date': u'2017-04-29T22:00:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Animals'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy poultry.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283613,
#    u'image': {u'id': 2505319, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapcherop'},
#    u'name': u'Loice',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T22:00:03Z',
#    u'posted_date': u'2017-04-29T22:00:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs such as good quality seeds, fertilizer and pesticides.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 50,
#    u'id': 1283188,
#    u'image': {u'id': 2505003, u'template_id': 1},
#    u'lender_count': 2,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.566667 34.566667',
#      u'type': u'point'},
#     u'town': u'Bungoma'},
#    u'name': u'Damaris',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T21:50:02Z',
#    u'posted_date': u'2017-04-29T21:50:02Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283594,
#    u'image': {u'id': 2505308, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Molo'},
#    u'name': u'Peter',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T21:30:02Z',
#    u'posted_date': u'2017-04-29T21:30:02Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283324,
#    u'image': {u'id': 2505107, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyahururu'},
#    u'name': u'Eunice',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T21:10:02Z',
#    u'posted_date': u'2017-04-29T21:10:02Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Elderly'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs to grow more crops on her horticulture farm.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283535,
#    u'image': {u'id': 2505269, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Rose',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T20:50:03Z',
#    u'posted_date': u'2017-04-29T20:50:03Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy fertilizers, pesticides and herbicides.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283454,
#    u'image': {u'id': 2505216, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Joseph',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T19:00:04Z',
#    u'posted_date': u'2017-04-29T19:00:04Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals for resale at his local market.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283444,
#    u'image': {u'id': 2505202, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsowar'},
#    u'name': u'Susan',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T18:50:05Z',
#    u'posted_date': u'2017-04-29T18:50:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy seeds to enable her grow more vegetables.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 250,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 50,
#    u'id': 1283410,
#    u'image': {u'id': 2505172, u'template_id': 1},
#    u'lender_count': 2,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'-0.333333 37.65',
#      u'type': u'point'},
#     u'town': u'Chuka'},
#    u'name': u'Fridah',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T18:40:06Z',
#    u'posted_date': u'2017-04-29T18:40:06Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'volunteer_like'}, {u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to purchase a water tank for harvesting rain water and water pipes for farm irrigation.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283418,
#    u'image': {u'id': 2505176, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Rebecca',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T18:30:05Z',
#    u'posted_date': u'2017-04-29T18:30:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs.'},
#   {u'activity': u'Dairy',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 50,
#    u'id': 1283259,
#    u'image': {u'id': 2504055, u'template_id': 1},
#    u'lender_count': 2,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kapsabet'},
#    u'name': u'Teresa',
#    u'partner_id': 133,
#    u'planned_expiration_date': u'2017-05-29T18:30:02Z',
#    u'posted_date': u'2017-04-29T18:30:02Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Animals'}],
#    u'use': u'to purchase a dairy cow for improved milk production.'},
#   {u'activity': u'Cereals',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1283173,
#    u'image': {u'id': 2504992, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nyamira'},
#    u'name': u'Monica',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-29T18:20:05Z',
#    u'posted_date': u'2017-04-29T18:20:05Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Repeat Borrower'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals.'},
#   {u'activity': u'Waste Management',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 125,
#    u'id': 1283221,
#    u'image': {u'id': 2504938, u'template_id': 1},
#    u'lender_count': 4,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Makadara, Nairobi.'},
#    u'name': u'Joseph',
#    u'partner_id': 258,
#    u'planned_expiration_date': u'2017-05-29T18:10:03Z',
#    u'posted_date': u'2017-04-29T18:10:03Z',
#    u'sector': u'Services',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'user_favorite'}],
#    u'themes': [u'Water and Sanitation', u'Innovative Loans'],
#    u'use': u'to pay for one Fresh Life toilet.'},
#   {u'activity': u'Waste Management',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 275,
#    u'id': 1283359,
#    u'image': {u'id': 2505056, u'template_id': 1},
#    u'lender_count': 10,
#    u'loan_amount': 275,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kwa Njenga, Mukuru, Nairobi.'},
#    u'name': u'Annah',
# ...
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 200,
#    u'id': 1278197,
#    u'image': {u'id': 2497961, u'template_id': 1},
#    u'lender_count': 6,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Bomet'},
#    u'name': u'Robert',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:40:02Z',
#    u'posted_date': u'2017-04-23T15:40:02Z',
#    u'sector': u'Agriculture',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs so as to improve his horticulture farm.'},
#   {u'activity': u'Fruits & Vegetables',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278192,
#    u'image': {u'id': 2497953, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 500,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Maua'},
#    u'name': u'Harun',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T15:30:03Z',
#    u'posted_date': u'2017-04-23T15:30:03Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#First Loan'},
#     {u'name': u'#Vegan'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'}],
#    u'use': u'to buy more stock of bananas for resale.'},
#   {u'activity': u'Cereals',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 200,
#    u'id': 1278178,
#    u'image': {u'id': 2497937, u'template_id': 1},
#    u'lender_count': 4,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.566667 34.566667',
#      u'type': u'point'},
#     u'town': u'Bungoma'},
#    u'name': u'Josphine',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:20:04Z',
#    u'posted_date': u'2017-04-23T15:20:04Z',
#    u'sector': u'Food',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy cereals to sell at her local market.'},
#   {u'activity': u'Farming',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 200,
#    u'id': 1278180,
#    u'image': {u'id': 2497938, u'template_id': 1},
#    u'lender_count': 6,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Bomet'},
#    u'name': u'Josephine',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:20:04Z',
#    u'posted_date': u'2017-04-23T15:20:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to purchase farm inputs (fertilizers, pesticides and herbicides).'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278181,
#    u'image': {u'id': 2497940, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.516667 35.283333',
#      u'type': u'point'},
#     u'town': u'Eldoret'},
#    u'name': u'Mary',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:20:04Z',
#    u'posted_date': u'2017-04-23T15:20:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}, {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm inputs (fertilizers, pesticides, and herbicides).'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278182,
#    u'image': {u'id': 2497942, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Nandi Hills'},
#    u'name': u'Prisca',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:20:04Z',
#    u'posted_date': u'2017-04-23T15:20:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'volunteer_pick'},
#     {u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy fertilizers, pesticides, and herbicides.'},
#   {u'activity': u'Farming',
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 200,
#    u'id': 1278183,
#    u'image': {u'id': 2497945, u'template_id': 1},
#    u'lender_count': 5,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Molo'},
#    u'name': u'Jane',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:20:04Z',
#    u'posted_date': u'2017-04-23T15:20:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'},
#     {u'name': u'#Biz Durable Asset'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to buy farm tools and equipment.'},
#   {u'activity': u'Farming',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': False,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278188,
#    u'image': {u'id': 2497949, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1.016667 35', u'type': u'point'},
#     u'town': u'Kitale'},
#    u'name': u'Evaline',
#    u'partner_id': 156,
#    u'planned_expiration_date': u'2017-05-23T15:20:04Z',
#    u'posted_date': u'2017-04-23T15:20:04Z',
#    u'sector': u'Agriculture',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'}],
#    u'themes': [u'Rural Exclusion'],
#    u'use': u'to purchase fertilizers, pesticides and herbicides.'},
#   {u'activity': u'Manufacturing',
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 925,
#    u'id': 1278185,
#    u'image': {u'id': 2497943, u'template_id': 1},
#    u'lender_count': 33,
#    u'loan_amount': 925,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'0.566667 34.566667',
#      u'type': u'point'},
#     u'town': u'Bungoma'},
#    u'name': u'James',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T15:20:03Z',
#    u'posted_date': u'2017-04-23T15:20:03Z',
#    u'sector': u'Manufacturing',
#    u'status': u'funded',
#    u'tags': [{u'name': u'user_favorite'},
#     {u'name': u'#Eco-friendly'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Repeat Borrower'}],
#    u'use': u'to buy materials for making energy-saving jikos (stoves).'},
#   {u'activity': u'Retail',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278174,
#    u'image': {u'id': 2497933, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 300,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Maua'},
#    u'name': u'Lucy',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T15:10:03Z',
#    u'posted_date': u'2017-04-23T15:10:03Z',
#    u'sector': u'Retail',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'volunteer_pick'},
#     {u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Vegan'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'}],
#    u'use': u'to buy more stock of cereals.'},
#   {u'activity': u'Restaurant',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 25,
#    u'id': 1278172,
#    u'image': {u'id': 2497928, u'template_id': 1},
#    u'lender_count': 1,
#    u'loan_amount': 775,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Maua'},
#    u'name': u'Moses',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T15:00:02Z',
#    u'posted_date': u'2017-04-23T15:00:02Z',
#    u'sector': u'Food',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'},
#     {u'name': u'#Schooling'},
#     {u'name': u'#Repeat Borrower'},
#     {u'name': u'#Biz Durable Asset'}],
#    u'use': u'to buy restaurant utensils and more ingredients for preparing food.'},
#   {u'activity': u'Retail',
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 500,
#    u'id': 1278160,
#    u'image': {u'id': 2497919, u'template_id': 1},
#    u'lender_count': 18,
#    u'loan_amount': 500,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Mwea'},
#    u'name': u'Dorothy',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T14:10:03Z',
#    u'posted_date': u'2017-04-23T14:10:03Z',
#    u'sector': u'Retail',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Single Parent'},
#     {u'name': u'#Repeat Borrower'}],
#    u'use': u'to buy more stock of shoes.'},
#   {u'activity': u'Metal Shop',
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 775,
#    u'id': 1278157,
#    u'image': {u'id': 2497913, u'template_id': 1},
#    u'lender_count': 30,
#    u'loan_amount': 775,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Ongata-Rongai'},
#    u'name': u'Geoffrey',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T13:50:02Z',
#    u'posted_date': u'2017-04-23T13:50:02Z',
#    u'sector': u'Manufacturing',
#    u'status': u'funded',
#    u'tags': [{u'name': u'user_favorite'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'},
#     {u'name': u'#Repeat Borrower'}],
#    u'use': u'to buy welding items.'},
#   {u'activity': u'Photography',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 25,
#    u'id': 1278137,
#    u'image': {u'id': 2497883, u'template_id': 1},
#    u'lender_count': 1,
#    u'loan_amount': 600,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Voi'},
#    u'name': u'Bernard',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T12:50:03Z',
#    u'posted_date': u'2017-04-23T12:50:03Z',
#    u'sector': u'Services',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}, {u'name': u'#Repeat Borrower'}],
#    u'use': u'to buy photography supplies.'},
#   {u'activity': u'Poultry',
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 500,
#    u'id': 1278115,
#    u'image': {u'id': 2497823, u'template_id': 1},
#    u'lender_count': 14,
#    u'loan_amount': 500,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kisauni'},
#    u'name': u'Maryanne',
#    u'partner_id': 164,
#    u'planned_expiration_date': u'2017-05-23T12:30:04Z',
#    u'posted_date': u'2017-04-23T12:30:05Z',
#    u'sector': u'Agriculture',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Animals'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Schooling'}],
#    u'use': u'to purchase chicks and poultry feeds.'},
#   {u'activity': u'Retail',
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 400,
#    u'id': 1278109,
#    u'image': {u'id': 2497800, u'template_id': 1},
#    u'lender_count': 14,
#    u'loan_amount': 400,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town',
#      u'pairs': u'-4.05 39.666667',
#      u'type': u'point'},
#     u'town': u'Mombasa'},
#    u'name': u'Margaret',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T12:30:03Z',
#    u'posted_date': u'2017-04-23T12:30:04Z',
#    u'sector': u'Retail',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#First Loan'},
#     {u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'}],
#    u'use': u'to buy more stocks of clothing and suitcases to sell.'},
#   {u'activity': u'Tailoring',
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 200,
#    u'id': 1278112,
#    u'image': {u'id': 2497816, u'template_id': 1},
#    u'lender_count': 5,
#    u'loan_amount': 200,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kisauni'},
#    u'name': u'Dhahabu',
#    u'partner_id': 164,
#    u'planned_expiration_date': u'2017-05-23T12:30:04Z',
#    u'posted_date': u'2017-04-23T12:30:04Z',
#    u'sector': u'Services',
#    u'status': u'funded',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Single Parent'},
#     {u'name': u'#Fabrics'}],
#    u'use': u'to purchase cloth materials and sewing thread for her business.'},
#   {u'activity': u'Retail',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278135,
#    u'image': {u'id': 2497875, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 500,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Voi'},
#    u'name': u'Dorothy',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T12:30:04Z',
#    u'posted_date': u'2017-04-23T12:30:04Z',
#    u'sector': u'Retail',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Woman Owned Biz'},
#     {u'name': u'#Vegan'},
#     {u'name': u'#Parent'},
#     {u'name': u'#Repeat Borrower'}],
#    u'use': u'to buy more stock of tomatoes, cabbages, potatoes, and kale.'},
#   {u'activity': u'Retail',
#    u'basket_amount': 0,
#    u'bonus_credit_eligibility': True,
#    u'borrower_count': 1,
#    u'description': {u'languages': [u'en']},
#    u'funded_amount': 0,
#    u'id': 1278111,
#    u'image': {u'id': 2497807, u'template_id': 1},
#    u'lender_count': 0,
#    u'loan_amount': 775,
#    u'location': {u'country': u'Kenya',
#     u'country_code': u'KE',
#     u'geo': {u'level': u'town', u'pairs': u'1 38', u'type': u'point'},
#     u'town': u'Kawangware'},
#    u'name': u'Paul',
#    u'partner_id': 138,
#    u'planned_expiration_date': u'2017-05-23T12:20:03Z',
#    u'posted_date': u'2017-04-23T12:20:03Z',
#    u'sector': u'Retail',
#    u'status': u'fundraising',
#    u'tags': [{u'name': u'#Parent'}, {u'name': u'#Repeat Borrower'}],
#    u'use': u'to buy more clothing stock.'}],
#  u'paging': {u'page': 1, u'page_size': 500, u'pages': 255, u'total': 127214}}

# %%
data = json.loads(d.text)

# %%
loans=json_normalize(data['loans'])

# %%
loans.head(3)
# Out:
#      activity  basket_amount bonus_credit_eligibility  borrower_count  \
# 0  Shoe Sales              0                    False               1
# 1  Food Stall              0                    False               1
# 2     Farming              0                    False               1
#
#   description.languages  funded_amount       id  image.id  image.template_id  \
# 0                  [en]              0  1284698   2506885                  1
# 1                  [en]              0  1284709   2506922                  1
# 2                  [en]              0  1284713   2506925                  1
#
#    lender_count                        ...                          \
# 0             0                        ...
# 1             0                        ...
# 2             0                        ...
#
#    location.town             name partner_id planned_expiration_date  \
# 0        Gatundu            Moses        388    2017-05-30T19:00:04Z
# 1     Kawangware  Francis Muchiri        262    2017-05-30T19:00:04Z
# 2        Bungoma          Jedidah        156    2017-05-30T19:00:03Z
#
#             posted_date       sector       status  \
# 0  2017-04-30T19:00:04Z       Retail  fundraising
# 1  2017-04-30T19:00:04Z         Food  fundraising
# 2  2017-04-30T19:00:03Z  Agriculture  fundraising
#
#                                                 tags             themes  \
# 0  [{u'name': u'#Parent'}, {u'name': u'#Schooling'}]                NaN
# 1                                                 []            [Youth]
# 2  [{u'name': u'#Woman Owned Biz'}, {u'name': u'#...  [Rural Exclusion]
#
#                                                  use
# 0  to buy more shoes for resale to meet customers...
# 1   to purchase a new grill and expand his business.
# 2  to buy good-quality seeds and fertilizer for h...
#
# [3 rows x 26 columns]

# %% [markdown]
# We have now extracted the first 500 rows of loans from the API. Now, we need to extract this data more systematically for all Kenyan loan results. KIVA has a parameter called page but does not allow for range of pages, so we will have to create a python loop to go through each page of results and add to our dataset.
