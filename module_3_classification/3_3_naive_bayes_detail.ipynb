# %% [markdown]
# # Naive Bayes
#
# Naive Bayes refers to the use of Bayes' theorem with naive independence assumptions between features.
#
# Naive Bayes classifers are popular for categorizing text. The goal of this module is to learn the basics of Naive Bayes and the ways Naive Bayes is improved for the purposes of sentiment analysis. The module is split into a few sections:
#
# + Prepare the data for analysis
# + Introduction to Naive Bayes
# + Improvement 1: Dealing with negation
# + Improvement 2: Bigrams
# + Improvement 3: Binary count Naive Bayes
# + Improvement 4: Dealing with Informal text
#
# This module coincides with our lecture on improving naive bayes for sentiment analysis.
#
# Before we delve into section 1 on data preparation, we will begin by doing an overview of the data we're using. For the reader's understanding of the methodology, we:
#
# 1. First, pulled the Twitter data related to microfinance using tweepy, a Twitter API library.
# 2. Next, we classified the comments into sentiment polarities in order to obtain training data for our model.
#     + Normally this process would require manually classifying ~20% of our data.
#     + In our exercise, we leveraged a simple wordnet algorithm called TextBlob to tag the entire data set.
# 3. We then manually reviewed and corrected classiications.
#     + (Note, if you are interested in seeing the code used to implement this, see the file titled "twitter_web_scraping.")

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import string
import nltk
# if you have never done so, you need to download stopwords from nltk
# nltk.download('stopwords')
# nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import train_test_split
import re
import itertools
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from wordcloud import WordCloud

from nltk.sentiment.util import mark_negation
from nltk import word_tokenize
# Out:
# /anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#load data and add a column for sentiment based on polarity
data = pd.read_csv("microfinance_tweets.csv", encoding="ISO-8859-1")

#check data to see if everything worked
data.head(10)
# Out:
#                                             Comments                 Date  \
# 0  RT @FINCA: Investors have been attracted to #m...  2018-10-07 19:36:17
# 1  https://t.co/OkspugKPI5 Determinants of the Pe...  2018-10-07 19:35:49
# 2  RT @FINCA: Investors have been attracted to #m...  2018-10-07 19:34:14
# 3  Investors have been attracted to #microfinance...  2018-10-07 19:02:00
# 4  RT @bilalhasanzaidi: @Xadeejournalist @Sccadi ...  2018-10-07 18:56:24
# 5  @Xadeejournalist @Sccadi @MuradSaeedPTI no the...  2018-10-07 18:52:07
# 6  There's still time to register for #EMW2018. D...  2018-10-07 18:45:43
# 7  âYes, We Created A More Sustainable and Equi...  2018-10-07 18:44:12
# 8  @SubDeliveryZone So your boyfriend MUST give y...  2018-10-07 18:17:12
# 9  RT @GC_BizFinance: Business Finance Director, ...  2018-10-07 18:13:54
#
#    Favorites                 User  Polarity Sentiment
# 0          0        syawalâ¢ ã·     0.000   neutral
# 1          0              NEP-MFD     0.000   neutral
# 2          0           #thefuture     0.000   neutral
# 3          2  FINCA International     0.000   neutral
# 4          0              Mehmood    -0.125  negative
# 5          1   Bilal Hassan Zaidi    -0.125  negative
# 6          0        NextBillionFH     0.000   neutral
# 7          0      Jomari Peterson     0.500  positive
# 8          5       Ugwunna Ejikem     0.000   neutral
# 9          0               Debbie     0.000   neutral

# %% [markdown]
# The Twitter data contains six columns:
# + Comments: the Twitter post that was made mentionining microfinance
# + Date: date the post was created on Twitter
# + Favorites: number of favorites the post has
# + User: name of the user who posted the comment
# + Polarity: the polarity, representing the degree of positivity versus negatvity that textblob deemed the post
# + Sentiment: a conversion of polarity into positive, negative, and neutral classifications
#
# Note that this exercise really does simulate what would happen in a real world situation. Our data is limited, and the process to get the quality training and test data we need (with labeled polarity) is a diffult one. To understand the nature of our data, we will conduct a few exercises below.

# %%
## What do we have for sentiment breakdown?
sns.countplot(x = 'Sentiment', data = data)
data['Sentiment'].value_counts()
# Out:
# neutral     1386
# positive     805
# negative     367
# Name: Sentiment, dtype: int64

# %% [markdown]
# It looks like most people have positive or neutral comments about microfinance. In fact, the volume of negative comments is the most interesting and should be investigated further.

# %%
## What are these negative comments?

#format columns so comments don't get cut off
pd.set_option('display.max_columns', None) 

#pull negative comments
data.loc[data['Sentiment'] == 'negative']['Comments'].unique()[0:10]
# Out:
# array(['RT @bilalhasanzaidi: @Xadeejournalist @Sccadi @MuradSaeedPTI no there are other ways too you just demonetize the currency and make exchangeâ\x80¦',
#        '@Xadeejournalist @Sccadi @MuradSaeedPTI no there are other ways too you just demonetize the currency and make exchaâ\x80¦ https://t.co/oPCiMKPlIB',
#        'Are you a small business looking for a #businessloan of up to â\x82¬25,000? Apply for a @Microfinanceire loan throughâ\x80¦ https://t.co/8zFcNwfZ9E',
#        'BIMAS Registry Assistant Jobs in Embu \n\nRegistry Assistant Job at BIMAS Kenya\n\nBIMAS Kenya Limited, a leading microâ\x80¦ https://t.co/CJ3AorYVXQ',
#        'RT @business: This developing nation has a big problem with small loans https://t.co/mJ1jn7RJhe',
#        'This Southeast Asian Nation Has a Big Problem With Small Loans https://t.co/qSap5SJRDv',
#        'We are still a long way from gender equality in India: Ananya Birla entrepreneur, #entrepreneur #entrepreneurshipâ\x80¦ https://t.co/6u708bkEMQ',
#        'Cambodia has a big problem with small loans https://t.co/EgAP5ZTOo0 @economics',
#        'RT economics "Cambodia has a big problem with small loans https://t.co/zAsNKQvbGs"',
#        'RT @economics: Cambodia has a big problem with small loans https://t.co/bc1ZYTYrTO'],
#       dtype=object)

# %% [markdown]
# It seems like some of the negative comments are not valid and should actually be classified as neutral. However, some of the negative comments are valid, e.g. illegal activity.
#
# Usually we would clean these classifications to correct it, but we will move forward to preparing our data for the model.

# %% [markdown]
# # Prepare data for the model
#
# The most common way to apply machine learning algorithms, such as Naive Bayes, to text analysis is to convert our text into numerical feature vectors that the algorithms can understand.
#
# The representation we will create is the **Bag of Words**. To get from our data, which is currently structured as a Series of strings, to a Bag of Words, we will **vectorize** our tweets.
#
# This **vectorization** of our text documents will require a few key steps, which we describe in more detail in [Module 8](https://docs.google.com/presentation/d/1vaxDuUROgaqix9Mfkyb4_h0cGkGwN7AUeLU1ozhtJW8/edit#slide=id.g227403103b_0_1171):
#
# Step 0. Split data into training and test sets (this is not part of vectorization) <br>
# Step 1. Clean and **tokenize** text <br>
# Step 2. Count the number of words in each document
#
# #### Step 0: Create training and test data
# This step should come naturally.
# We have classified sentiments for all our data, and we choose an 80-20 training and test split, with observations assigned at random.

# %%
# A) Create a set of test (20% of data) and training (80% of data) data
# We set a seed so this can be reproducible
np.random.seed(12345)
msk = np.random.rand(len(data)) < 0.8
train = data[msk]
test = data[~msk]

# %%
# Be sure to check the length of the training and test sets to confirm data was split in the correct porportions
print(len(train), len(test))
print("Split of {:.2%} train, {:.2%} test".format(len(train)/len(data), len(test)/len(data)))
# Out:
# 2042 516
# Split of 79.83% train, 20.17% test

# %% [markdown]
# #### Step 1: Clean and Tokenize Text
#
# As mentioned, the most common way to extract numerical vectors from text is to have a set of text **tokens** for which we can have counts.
#
# **Tokenization** means to convert a document/sentence/tweet into individual *tokens*, which are usually words, or word-like units.
#
# When creating these word-like tokens, we want to standardize them in a way that groups words with similar intent. This makes these token features more useful than unprocessed words. Check out the [NLP Module](https://docs.google.com/presentation/d/1vaxDuUROgaqix9Mfkyb4_h0cGkGwN7AUeLU1ozhtJW8/edit#slide=id.g227403103b_0_1050) for more details!
#
# We create a function to
# + **lemmatize** these words
# + remove *stop words*, punctuation, URLs, numbers, and special characters
#
# Luckily, NLTK has different libraries that make this task very easy.

# %%
# B) Lemmatize words, and remove stop words and punctuation
lemmatizer = WordNetLemmatizer()

def text_process(text):
    '''
    Takes in a string of text, then performs the following:
    1. Remove URLs
    2. Remove punctuation
    3. Remove numbers
    4. Remove stopwords
    5. Return the cleaned text as a list of lemmatized words
    '''
    
    text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text, flags=re.MULTILINE)
    
    text = ''.join([t for t in text if t not in string.punctuation])
    
    text = ''.join([t for t in text if not t.isdigit()])
    
    return [lemmatizer.lemmatize(word) for word in text.split() if word.lower() not in stopwords.words('english')]

# %%
# Let's test the function to make sure it's doing what we would expect
sample_text = "I LOVE love BBQ chicken pizza. I eat it every day, but sometimes I wonder if I'm being unhealthy https://ilove.pizza"
text_process(sample_text)
# Out:
# ['LOVE',
#  'love',
#  'BBQ',
#  'chicken',
#  'pizza',
#  'eat',
#  'every',
#  'day',
#  'sometimes',
#  'wonder',
#  'Im',
#  'unhealthy']

# %% [markdown]
# #### Step 2) Count the number of words in each 'document'
#
# This is the step that brings our text to the representation as a *Bag of Words*.
#
# A bag of words allows us to work with free text in a structured way. We use a simple count for our bag of words, but TF-IDF sklearn libraries are also available and can be used for other NLP problems.
#
# We use the **CountVectorization** function from the sklearn library.
#
# The TF-IDF Vectorizer is available by using:
#
# `from sklearn.feature_extraction.text import TfidfVectorizer`
#
# Note the difference in the use of the functions for fitting bag of words for test versus training data.

# %%
# C) Represent the text in a bag-of-words by leveraging CountVectorization in the sklearn library.
vectorizer = CountVectorizer(analyzer=text_process)
train_features = vectorizer.fit_transform(train['Comments'])
test_features =  vectorizer.transform(test['Comments'])

# %%
vectorizer.get_feature_names()[0:20]
# Out:
# ['AB',
#  'ABSwift',
#  'ACTION',
#  'ADB',
#  'ADDOSSER',
#  'ADK',
#  'ADKã\x83\x9bã\x83«ã\x83\x80ã\x83¼ã\x81\x8aã\x82\x81ã\x81§ã\x81¨ã\x83¼',
#  'AFRIQUE',
#  'AGENTS',
#  'AGFUND',
#  'AGFUNDProgram',
#  'AGM',
#  'AGMâ\x80¦',
#  'AIDs',
#  'ALERT',
#  'AMIFA',
#  'AMicrofinanzas',
#  'APPLY',
#  'ASA',
#  'ATLANTIC']

# %% [markdown]
# These are our *features*, i.e. all of the cleaned tokens from all of the tweets. A training or test tweet can now be represented as a count of how many times any of these features shows up.

# %%
# Test the vectorizer by looking at the size of the vectors and snippets of the vectors
print('Length of Vectorizer Vocabulary: ', len(vectorizer.vocabulary_))
print('Shape of Sparse Matrix: ', test_features.shape)
print('Amount of Non-Zero occurrences: ', test_features.nnz)

# Percentage of non-zero values
density = 100.0 * (test_features.nnz / (test_features.shape[0] * test_features.shape[1]))
print('Density: {}'.format((density)))
# Out:
# Length of Vectorizer Vocabulary:  4679
# Shape of Sparse Matrix:  (516, 4679)
# Amount of Non-Zero occurrences:  5555
# Density: 0.23008129677215197

# %% [markdown]
# We have 4890 *tokens* in our corpus. The test data features matrix is a representation of each of the 647 tweets as a vector of token counts.

# %%
# To understand how the vectorizer stores words, we will input a sample test data review
sample_test = test['Comments'].iloc[0]
print("Sample comment: ", sample_test, "\n")
sample_vector = vectorizer.transform([sample_test])
print("Vectorization:")
print(sample_vector)
# Out:
# Sample comment:  RT @FINCA: Investors have been attracted to #microfinance not only because donors and DFIs de-risked the business model but also because ofâ¦
#
# Vectorization:
#   (0, 417)	1
#   (0, 588)	1
#   (0, 850)	1
#   (0, 1472)	1
#   (0, 2005)	1
#   (0, 2085)	1
#   (0, 2209)	1
#   (0, 2454)	1
#   (0, 2518)	1
#   (0, 3291)	1
#   (0, 3333)	1
#   (0, 3444)	1

# %%
# This means we have a word count for a word at index 755, 925, etc.
# We can use get_feature_names() on the vectorizer to see what these words are
print(list(vectorizer.get_feature_names()[i] for i in sample_vector.indices))
# Out:
# ['DFIs', 'FINCA', 'Investors', 'RT', 'also', 'attracted', 'business', 'derisked', 'donor', 'microfinance', 'model', 'ofâ\x80¦']

# %% [markdown]
# Let's look at a Wordcloud of our data to see what words are most frequently showing up!

# %%
cloud = WordCloud(width=1600, height=1200).generate(" ".join(data['Comments'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1599.5, 1199.5, -0.5)

# %% [markdown]
# We still appear to have some urls, and Telenor seems to be a big deal.

# %% [markdown]
# # Introduction to Naive Bayes
# We will begin by running Naive Bayes on the text and check how well it does in predicting classifications. This step is very easy given we have already prepared out data in a bag of words format. <br>

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 87.79%'

# %% [markdown]
# The accuracy is high at ~84%. Most sentiment analysis algorithms have an accuarcy of ~80% when you have fitted the model on proper training data. In this case, the 84% accuracy is likely inflated because we've used TextBlob to determine the correct sentiment in our training data.
#
# The current measurement of accuracy is a one-dimensional value. We don't know what we're messing up when we classify the sentiments wrong. One tool to better understand how we're misclassifying is called a confusion matrix (first introduced in module X: Logistic Regression.)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
class_names = set(data['Sentiment'])
cnf_matrix = confusion_matrix(test['Sentiment'], preds)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, basic NB')

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 59   2   3]
#  [ 17 253  27]
#  [  3  11 141]]
# Normalized confusion matrix
# [[0.921875   0.03125    0.046875  ]
#  [0.05723906 0.85185185 0.09090909]
#  [0.01935484 0.07096774 0.90967742]]

# %% [markdown]
# The above results show that we're commonly predicting positive comments as netural. This misclassification is not as concerning as our second common misclassification of negative comments as positive.

# %% [markdown]
# # Improvement 1: Dealing with Negation
#
# To improve on simple Naive Bayes for sentiment analysis, we can adjust our tokenizer for negation in sentences. (See module 10 lecture slides for full details.) Mark negation is a library we can use in NLTK that appends a "_NEG" to words after a negation until a punctuation mark. This means that the words after a negation will be handled differently than the words before a negation. We can investgate whether using negation will improve our model. Given wordnet did not classify negation properly, this method will unfortunately probably not improve the model.

# %%
# Example of mark_negation
print(mark_negation("I like BBQ chicken pizza . I like pepperoni pizza.".split()))
print(mark_negation("I don't like BBQ chicken pizza . I like pepperoni pizza only .".split()))

# Test using mark_negation with text_process
text = "I don't like BBQ chicken pizza. I like pepperoni pizza only."
print(mark_negation(text_process(text)))
# Out:
# ['I', 'like', 'BBQ', 'chicken', 'pizza', '.', 'I', 'like', 'pepperoni', 'pizza.']
# ['I', "don't", 'like_NEG', 'BBQ_NEG', 'chicken_NEG', 'pizza_NEG', '.', 'I', 'like', 'pepperoni', 'pizza', 'only', '.']
# ['dont', 'like_NEG', 'BBQ_NEG', 'chicken_NEG', 'pizza_NEG', 'like_NEG', 'pepperoni_NEG', 'pizza_NEG']

# %%
# To incorporate it into our Naive Bayes model, we will need to adjust how we process our data in creating a bag of words
vectorizer_negation = CountVectorizer(analyzer='word', tokenizer = lambda text: mark_negation(text_process(text)))
train_features_negation = vectorizer_negation.fit_transform(train['Comments'])
test_features_negation = vectorizer_negation.transform(test['Comments'])

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_negation, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_negation)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 84.30%'

# %% [markdown]
# As predicted, using negation has not improved our accuracy. In fact, it makes it worse!

# %% [markdown]
# # Improvement 2: Bigrams
# What if we tried using bigrams instead? How would using bigrams change the accuracy of our model? Usually including bigrams is a good model booster for any kind of Naive Bayes model, not just sentiment analysis. CountVectorizer makes it easy for us to input bigrams into our Naive Bayes model with a ngram_range parameter. The first value in the tuple specifies the lowest ngram we will track, and the second, the highest. In this case, we will consider both unigrams and bigrams. <br>

# %%
#Use bigrams with countvectorizer
vectorizer_bigrams = CountVectorizer(analyzer="word", ngram_range = (1,2), encoding='ISO-8859-1', lowercase=False)
train_features_bigrams = vectorizer_bigrams.fit_transform(train['Comments'])
test_features_bigrams  = vectorizer_bigrams.transform(test['Comments'])

# %%
#test the bigrams function worked as expected
vectorizer_bigrams.vocabulary_
# Out:
# {'https': 11507,
#  'co': 8286,
#  'OkspugKPI5': 4523,
#  'Determinants': 1833,
#  'of': 13573,
#  'the': 15829,
#  'Performance': 4738,
#  'Microfinance': 3887,
#  'Institutions': 3021,
#  'Systematic': 5850,
#  'Review': 5327,
#  'Niels': 4365,
#  'Heâ': 2764,
#  'ItIjOQrsGz': 3098,
#  'https co': 11508,
#  'co OkspugKPI5': 8717,
#  'OkspugKPI5 Determinants': 4524,
#  'Determinants of': 1834,
#  'of the': 13713,
#  'the Performance': 15887,
#  'Performance of': 4740,
#  'of Microfinance': 13617,
#  'Microfinance Institutions': 3927,
#  'Institutions Systematic': 3022,
#  'Systematic Review': 5851,
#  'Review Niels': 5328,
#  'Niels Heâ': 4367,
#  'Heâ https': 2765,
#  'co ItIjOQrsGz': 8628,
#  'RT': 4971,
#  'FINCA': 2209,
#  'Investors': 3065,
#  'have': 11304,
#  'been': 7724,
#  'attracted': 7474,
#  'to': 16253,
#  'microfinance': 12954,
#  'not': 13464,
#  'only': 13855,
#  'because': 7709,
#  'donors': 10019,
#  'and': 7009,
#  'DFIs': 1725,
#  'de': 9728,
#  'risked': 14889,
#  'business': 7945,
#  'model': 13185,
#  'but': 7974,
#  'also': 6904,
#  'ofâ': 13766,
#  'RT FINCA': 5014,
#  'FINCA Investors': 2214,
#  'Investors have': 3066,
#  'have been': 11311,
#  'been attracted': 7726,
#  'attracted to': 7476,
#  'to microfinance': 16378,
#  'microfinance not': 13045,
#  'not only': 13476,
#  'only because': 13856,
#  'because donors': 7710,
#  'donors and': 10020,
#  'and DFIs': 7020,
#  'DFIs de': 1726,
#  'de risked': 9755,
#  'risked the': 14890,
#  'the business': 15914,
#  'business model': 7956,
#  'model but': 13186,
#  'but also': 7976,
#  'also because': 6906,
#  'because ofâ': 7715,
#  'alâ': 6916,
#  'sDIibWWhvy': 14961,
#  'but alâ': 7977,
#  'alâ https': 6917,
#  'co sDIibWWhvy': 9218,
#  'bilalhasanzaidi': 7814,
#  'Xadeejournalist': 6534,
#  'Sccadi': 5533,
#  'MuradSaeedPTI': 4163,
#  'no': 13428,
#  'there': 16131,
#  'are': 7262,
#  'other': 13960,
#  'ways': 16900,
#  'too': 16475,
#  'you': 17307,
#  'just': 12194,
#  'demonetize': 9805,
#  'currency': 9646,
#  'make': 12768,
#  'exchangeâ': 10375,
#  'RT bilalhasanzaidi': 5145,
#  'bilalhasanzaidi Xadeejournalist': 7815,
#  'Xadeejournalist Sccadi': 6535,
#  'Sccadi MuradSaeedPTI': 5534,
#  'MuradSaeedPTI no': 4164,
#  'no there': 13434,
#  'there are': 16132,
#  'are other': 7296,
#  'other ways': 13963,
#  'ways too': 16902,
#  'too you': 16477,
#  'you just': 17329,
#  'just demonetize': 12197,
#  'demonetize the': 9806,
#  'the currency': 15929,
#  'currency and': 9647,
#  'and make': 7118,
#  'make exchangeâ': 12772,
#  'exchaâ': 10376,
#  'oPCiMKPlIB': 13550,
#  'make exchaâ': 12773,
#  'exchaâ https': 10377,
#  'co oPCiMKPlIB': 9149,
#  'Yes': 6571,
#  'We': 6381,
#  'Created': 1663,
#  'More': 4114,
#  'Sustainable': 5837,
#  'Equitable': 2103,
#  'Currency': 1686,
#  'With': 6480,
#  'Denariiâ': 1824,
#  'goal': 11081,
#  'Eliminate': 2050,
#  'Predatory': 4829,
#  'Lendingâ': 3473,
#  'yrn8uZRAij': 17389,
#  'Yes We': 6572,
#  'We Created': 6383,
#  'Created More': 1664,
#  'More Sustainable': 4116,
#  'Sustainable and': 5838,
#  'and Equitable': 7022,
#  'Equitable Currency': 2104,
#  'Currency With': 1687,
#  'With Denariiâ': 6481,
#  'Denariiâ the': 1825,
#  'the goal': 15968,
#  'goal Eliminate': 11082,
#  'Eliminate Predatory': 2051,
#  'Predatory Lendingâ': 4830,
#  'Lendingâ https': 3474,
#  'co yrn8uZRAij': 9335,
#  'SubDeliveryZone': 5812,
#  'So': 5700,
#  'your': 17355,
#  'boyfriend': 7892,
#  'MUST': 3749,
#  'give': 11047,
#  'money': 13195,
#  'start': 15462,
#  'big': 7804,
#  'as': 7356,
#  'per': 14171,
#  'bank': 7567,
#  'that': 15788,
#  'he': 11335,
#  'iâ': 12129,
#  'jeedj1wdp6': 12149,
#  'SubDeliveryZone So': 5813,
#  'So your': 5706,
#  'your boyfriend': 17360,
#  'boyfriend MUST': 7893,
#  'MUST give': 3750,
#  'give you': 11051,
#  'you money': 17332,
#  'money to': 13204,
#  'to start': 16420,
#  'start big': 15463,
#  'big business': 7805,
#  'business as': 7950,
#  'as per': 7377,
#  'per microfinance': 14172,
#  'microfinance bank': 12984,
#  'bank that': 7592,
#  'that he': 15807,
#  'he iâ': 11338,
#  'iâ https': 12130,
#  'co jeedj1wdp6': 9067,
#  'GC_BizFinance': 2459,
#  'Business': 1275,
#  'Finance': 2307,
#  'Director': 1863,
#  'Paul': 4708,
#  'Breen': 1251,
#  'talking': 15681,
#  'around': 7326,
#  'Technological': 5924,
#  'Innovation': 3009,
#  'for': 10721,
#  'MFIâ': 3697,
#  'at': 7419,
#  'MFC': 3658,
#  'EMN': 1944,
#  'Annual': 772,
#  'conferencâ': 9456,
#  'RT GC_BizFinance': 5019,
#  'GC_BizFinance Business': 2460,
#  'Business Finance': 1276,
#  'Finance Director': 2314,
#  'Director Paul': 1867,
#  'Paul Breen': 4709,
#  'Breen talking': 1252,
#  'talking around': 15683,
#  'around Technological': 7328,
#  'Technological Innovation': 5925,
#  'Innovation for': 3010,
#  'for MFIâ': 10736,
#  'MFIâ at': 3698,
#  'at the': 7458,
#  'the MFC': 15876,
#  'MFC EMN': 3661,
#  'EMN Annual': 1945,
#  'Annual conferencâ': 777,
#  'TGV': 5867,
#  'engage': 10223,
#  'mettre': 12914,
#  'en': 10191,
#  'place': 14221,
#  'un': 16602,
#  'systÃ': 15627,
#  'me': 12848,
#  'cautionnement': 8133,
#  'municipal': 13272,
#  'la': 12323,
#  'Cocody': 1567,
#  'CocodyRenaissance': 1569,
#  'jZhD1t0rK3': 12138,
#  'TGV engage': 5868,
#  'engage mettre': 10226,
#  'mettre en': 12915,
#  'en place': 10199,
#  'place un': 14222,
#  'un systÃ': 16610,
#  'systÃ me': 15628,
#  'me de': 12852,
#  'de cautionnement': 9736,
#  'cautionnement municipal': 8134,
#  'municipal de': 13273,
#  'de la': 9742,
#  'la microfinance': 12337,
#  'microfinance Cocody': 12960,
#  'Cocody CocodyRenaissance': 1568,
#  'CocodyRenaissance https': 1570,
#  'co jZhD1t0rK3': 9063,
#  'LendLedger': 3464,
#  'What': 6435,
#  'makes': 12777,
#  'different': 9880,
#  'For': 2384,
#  'one': 13837,
#  'thing': 16154,
#  'we': 16905,
#  're': 14630,
#  'built': 7934,
#  'out': 14002,
#  'from': 10895,
#  'Happy': 2716,
#  'Loans': 3563,
#  'which': 16998,
#  'provided': 14473,
#  'million': 13136,
#  'loans': 12628,
#  '15': 105,
#  '0â': 63,
#  'RT LendLedger': 5052,
#  'LendLedger What': 3466,
#  'What makes': 6438,
#  'makes LendLedger': 12778,
#  'LendLedger different': 3467,
#  'different For': 9882,
#  'For one': 2396,
#  'one thing': 13847,
#  'thing we': 16156,
#  'we re': 16916,
#  're built': 14631,
#  'built out': 7936,
#  'out from': 14004,
#  'from Happy': 10906,
#  'Happy Loans': 2719,
#  'Loans which': 3565,
#  'which provided': 17003,
#  'provided million': 14474,
#  'million of': 13142,
#  'of loans': 13687,
#  'loans to': 12647,
#  'to 15': 16257,
#  '15 0â': 107,
#  'Link': 3542,
#  'credit': 9590,
#  'bureausâ': 7943,
#  'UGBS': 6139,
#  'report': 14784,
#  'amp': 6939,
#  'Financial': 2324,
#  'Times': 6064,
#  'Online': 4542,
#  'oQs4CXIWD5': 13551,
#  'Link Microfinance': 3543,
#  'Institutions to': 3024,
#  'to credit': 16322,
#  'credit bureausâ': 9597,
#  'bureausâ UGBS': 7944,
#  'UGBS report': 6140,
#  'report Business': 14785,
#  'Business amp': 1278,
#  'amp Financial': 6946,
#  'Financial Times': 2330,
#  'Times Online': 6065,
#  'Online https': 4543,
#  'co oQs4CXIWD5': 9150,
#  'ATLANTIC': 563,
#  'MICROFINANCE': 3715,
#  'CI': 1363,
#  'RECRUTE': 4945,
#  'GESTIONNAIRE': 2463,
#  'DE': 1723,
#  'RECOUVREMENT': 4941,
#  'jar3ynTNx1': 12141,
#  'ATLANTIC MICROFINANCE': 564,
#  'MICROFINANCE CI': 3718,
#  'CI RECRUTE': 1364,
#  'RECRUTE GESTIONNAIRE': 4946,
#  'GESTIONNAIRE DE': 2464,
#  'DE RECOUVREMENT': 1724,
#  'RECOUVREMENT https': 4942,
#  'co jar3ynTNx1': 9064,
#  'CharlesDlmd': 1500,
#  'Il': 2920,
#  'pense': 14147,
#  'encore': 10206,
#  'sa': 14973,
#  'pute': 14521,
#  'Si': 5629,
#  'une': 16626,
#  'meuf': 12916,
#  'chante': 8196,
#  'au': 7481,
#  'micro': 12929,
#  'homme': 11457,
#  'et': 10308,
#  'qu': 14547,
#  'aprÃ': 7257,
#  'il': 11567,
#  'lui': 12717,
#  'donne': 10015,
#  'argent': 7322,
#  'on': 13777,
#  'peut': 14191,
#  'dirâ': 9925,
#  'RT CharlesDlmd': 4994,
#  'CharlesDlmd Il': 1501,
#  'Il pense': 2921,
#  'pense encore': 14148,
#  'encore sa': 10207,
#  'sa pute': 14974,
#  'pute Si': 14522,
#  'Si une': 5630,
#  'une meuf': 16629,
#  'meuf chante': 12917,
#  'chante au': 8197,
#  'au micro': 7485,
#  'micro un': 12935,
#  'un homme': 16606,
#  'homme et': 11458,
#  'et qu': 10318,
#  'qu aprÃ': 14548,
#  'aprÃ il': 7258,
#  'il lui': 11570,
#  'lui donne': 12718,
#  'donne de': 10017,
#  'de argent': 9734,
#  'argent on': 7325,
#  'on peut': 13821,
#  'peut dirâ': 14192,
#  'COL4D': 1383,
#  'Tanzania': 5904,
#  'women': 17136,
#  'turn': 16547,
#  'entrepreneurs': 10257,
#  'with': 17069,
#  'soft': 15360,
#  'loan': 12606,
#  'Learn': 3452,
#  'more': 13225,
#  'qZ8BEgoxnX': 14537,
#  'PgcgNtY1k5': 4755,
#  'RT COL4D': 4992,
#  'COL4D Tanzania': 1384,
#  'Tanzania women': 5905,
#  'women turn': 17157,
#  'turn entrepreneurs': 16548,
#  'entrepreneurs with': 10262,
#  'with microfinance': 17099,
#  'microfinance soft': 13063,
#  'soft loan': 15361,
#  'loan Learn': 12608,
#  'Learn more': 3455,
#  'more https': 13231,
#  'co qZ8BEgoxnX': 9189,
#  'qZ8BEgoxnX https': 14538,
#  'co PgcgNtY1k5': 8730,
#  'GildaHezek': 2560,
#  'Be': 1119,
#  'Socially': 5713,
#  'responsible': 14833,
#  'HASAL': 2675,
#  'BANK': 931,
#  'engages': 10230,
#  'in': 11615,
#  '2hrs': 262,
#  '10mins': 79,
#  'Health': 2738,
#  'Walk': 6362,
#  'Abuja': 592,
#  'hasal2018CSRevents': 11291,
#  'RT GildaHezek': 5021,
#  'GildaHezek Be': 2561,
#  'Be Socially': 1120,
#  'Socially responsible': 5714,
#  'responsible HASAL': 14834,
#  'HASAL MICROFINANCE': 2676,
#  'MICROFINANCE BANK': 3716,
#  'BANK engages': 936,
#  'engages in': 10231,
#  'in 2hrs': 11619,
#  '2hrs 10mins': 263,
#  '10mins Health': 80,
#  'Health Walk': 2739,
#  'Walk in': 6364,
#  'in Abuja': 11620,
#  'Abuja hasal2018CSRevents': 593,
#  'hasal2018CSRevents https': 11292,
#  'MfbHASAL': 3860,
#  'Heart': 2740,
#  'Disease': 1881,
#  'awareness': 7529,
#  'health': 11344,
#  'walk': 16861,
#  'GildaHezek MfbHASAL': 2562,
#  'MfbHASAL Be': 3861,
#  '2hrs Heart': 264,
#  'Heart Disease': 2741,
#  'Disease awareness': 1882,
#  'awareness health': 7530,
#  'health walk': 11347,
#  'walk in': 16862,
#  'hasalmfb2018CSRevents': 11295,
#  'RT MfbHASAL': 5068,
#  'MfbHASAL HASAL': 3862,
#  'Abuja hasalmfb2018CSRevents': 594,
#  'hasalmfb2018CSRevents https': 11296,
#  'Ltd': 3601,
#  'is': 11980,
#  '10': 64,
#  'years': 17283,
#  'old': 13770,
#  'grateful': 11130,
#  'our': 13969,
#  'loyal': 12702,
#  'customers': 9659,
#  'celebrate': 8151,
#  'supportingâ': 15596,
#  'BANK Ltd': 935,
#  'Ltd is': 3611,
#  'is 10': 11981,
#  '10 years': 72,
#  'years old': 17289,
#  'old We': 13772,
#  'We are': 6384,
#  'are grateful': 7280,
#  'grateful to': 11131,
#  'to our': 16390,
#  'our loyal': 13986,
#  'loyal customers': 12703,
#  'customers as': 9663,
#  'as we': 7383,
#  'we celebrate': 16908,
#  'celebrate 10': 8152,
#  'years of': 17288,
#  'of supportingâ': 13710,
#  'supporting': 15593,
#  'MSME': 3742,
#  'growth': 11171,
#  'Inclusion': 2960,
#  'And': 760,
#  'sustainable': 15609,
#  'Operations': 4558,
#  'hâ': 11538,
#  'MfbHASAL We': 3863,
#  'We celebrate': 6386,
#  'of supporting': 13709,
#  'supporting MSME': 15594,
#  'MSME growth': 3743,
#  'growth amp': 11174,
#  'Financial Inclusion': 2327,
#  'Inclusion And': 2961,
#  'And 10': 761,
#  'of sustainable': 13711,
#  'sustainable Microfinance': 15610,
#  'Microfinance Operations': 3947,
#  'Operations hâ': 4559,
#  'Are': 816,
#  'small': 15319,
#  'looking': 12675,
#  'businessloan': 7966,
#  'up': 16662,
#  '25': 222,
#  '000': 3,
#  'Apply': 807,
#  'Microfinanceire': 4014,
#  'throughâ': 16216,
#  '8zFcNwfZ9E': 483,
#  'Are you': 818,
#  'you small': 17342,
#  'small business': 15321,
#  'business looking': 7955,
#  'looking for': 12677,
#  'for businessloan': 10766,
#  'businessloan of': 7967,
#  'of up': 13721,
#  'up to': 16674,
#  'to 25': 16259,
#  '25 000': 223,
#  '000 Apply': 7,
#  'Apply for': 810,
#  'for Microfinanceire': 10739,
#  'Microfinanceire loan': 4016,
#  'loan throughâ': 12626,
#  'throughâ https': 16217,
#  'co 8zFcNwfZ9E': 8446,
#  'Tau_Moyo': 5910,
#  'MarioWuragu': 3815,
#  'Banking': 1067,
#  'officials': 13759,
#  'Central': 1477,
#  'Bank': 1022,
#  'houses': 11481,
#  'running': 14926,
#  'streets': 15520,
#  'Ask': 846,
#  'yourself': 17380,
#  'how': 11489,
#  'doâ': 10033,
#  'RT Tau_Moyo': 5116,
#  'Tau_Moyo MarioWuragu': 5911,
#  'MarioWuragu We': 3816,
#  'We have': 6389,
#  'have Banking': 11305,
#  'Banking officials': 1074,
#  'officials from': 13760,
#  'from the': 10926,
#  'the Central': 15848,
#  'Central Bank': 1478,
#  'Bank of': 1058,
#  'Microfinance houses': 3984,
#  'houses running': 11482,
#  'running the': 14929,
#  'the streets': 16068,
#  'streets Ask': 15521,
#  'Ask yourself': 847,
#  'yourself how': 17381,
#  'how doâ': 11497,
#  'yourseâ': 17382,
#  '3ueEHWPxaX': 308,
#  'Ask yourseâ': 848,
#  'yourseâ https': 17383,
#  'co 3ueEHWPxaX': 8352,
#  '1DL1zmvU9M': 134,
#  'In': 2938,
#  'Interview': 3045,
#  'ASA': 559,
#  'Pakistan': 4677,
#  'Institution': 3016,
#  'Sindh': 5649,
#  'Punjab': 4903,
#  'co 1DL1zmvU9M': 8311,
#  '1DL1zmvU9M Walk': 135,
#  'Walk In': 6363,
#  'In Interview': 2947,
#  'Interview ASA': 3046,
#  'ASA Pakistan': 560,
#  'Pakistan Ltd': 4679,
#  'Ltd Microfinance': 3604,
#  'Microfinance Institution': 3926,
#  'Institution For': 3017,
#  'For Sindh': 2394,
#  'Sindh and': 5651,
#  'and Punjab': 7050,
#  'Anti': 785,
#  'Terrorism': 5942,
#  'Court': 1655,
#  'Jobs': 3179,
#  'Advans': 644,
#  'Khairpur': 3303,
#  'Ghotki': 2558,
#  'Navy': 4291,
#  'Anti Terrorism': 786,
#  'Terrorism Court': 5943,
#  'Court Sindh': 1656,
#  'Sindh Jobs': 5650,
#  'Jobs Advans': 3181,
#  'Advans Pakistan': 646,
#  'Pakistan Microfinance': 4680,
#  'Microfinance Bank': 3896,
#  'Bank Khairpur': 1031,
#  'Khairpur amp': 3305,
#  'amp Ghotki': 6948,
#  'Ghotki Jobs': 2559,
#  'Jobs Pakistan': 3183,
#  'Pakistan Navy': 4682,
#  'Navy Jobs': 4292,
#  'SAB_Banking': 5390,
#  'Fully': 2437,
#  'tune': 16540,
#  'MFIs': 3683,
#  'need': 13347,
#  'real': 14661,
#  'core': 9521,
#  'banking': 7599,
#  'system': 15619,
#  'CBS': 1325,
#  'ZUrhH7IPyy': 6614,
#  'WbX8Z2ELre': 6380,
#  'RT SAB_Banking': 5104,
#  'SAB_Banking Fully': 5391,
#  'Fully in': 2438,
#  'in tune': 11747,
#  'tune with': 16541,
#  'with you': 17114,
#  'you MFIs': 17309,
#  'MFIs need': 3689,
#  'need real': 13354,
#  'real core': 14662,
#  'core banking': 9522,
#  'banking system': 7607,
#  'system CBS': 15620,
#  'CBS https': 1326,
#  'co ZUrhH7IPyy': 8906,
#  'ZUrhH7IPyy https': 6615,
#  'co WbX8Z2ELre': 8860,
#  'Le': 3437,
#  'groupe': 11154,
#  'tunisien': 16542,
#  'Horchani': 2792,
#  'se': 15070,
#  'renforce': 14773,
#  'dans': 9700,
#  'le': 12406,
#  'capital': 8096,
#  'Taysir': 5912,
#  'm6tXE113vY': 12731,
#  'sHjx8tO9zd': 14965,
#  'Le groupe': 3441,
#  'groupe tunisien': 11156,
#  'tunisien Horchani': 16543,
#  'Horchani se': 2799,
#  'se renforce': 15074,
#  'renforce dans': 14774,
#  'dans le': 9702,
#  'le capital': 12411,
#  'capital de': 8098,
#  'de Taysir': 9732,
#  'Taysir Microfinance': 5913,
#  'Microfinance https': 3985,
#  'co m6tXE113vY': 9109,
#  'm6tXE113vY https': 12732,
#  'co sHjx8tO9zd': 9222,
#  'FINCAImpact': 2231,
#  'announces': 7193,
#  'USD': 6170,
#  '20': 152,
#  'facility': 10460,
#  'BlueOrchardLtd': 1205,
#  'Enhancement': 2075,
#  'Facility': 2268,
#  'SAâ': 5396,
#  'mgRlVu5hhh': 12923,
#  'FINCAImpact announces': 2233,
#  'announces USD': 7195,
#  'USD 20': 6171,
#  '20 million': 156,
#  'million loan': 13140,
#  'loan facility': 12614,
#  'facility with': 10461,
#  'with BlueOrchardLtd': 17071,
#  'BlueOrchardLtd and': 1206,
#  'and Microfinance': 7040,
#  'Microfinance Enhancement': 3916,
#  'Enhancement Facility': 2076,
#  'Facility SAâ': 2271,
#  'SAâ https': 5397,
#  'co mgRlVu5hhh': 9125,
#  'Nirdhan_Utthan_Microfinance': 4391,
#  'conducts': 9441,
#  'range': 14606,
#  'agricultural': 6832,
#  'training': 16491,
#  'rural': 14937,
#  'folks': 10708,
#  'Kailali': 3257,
#  'Kanchanpur': 3263,
#  'Veh8rtfD2o': 6294,
#  'Nirdhan_Utthan_Microfinance conducts': 4392,
#  'conducts range': 9442,
#  'range of': 14607,
#  'of agricultural': 13644,
#  'agricultural training': 6834,
#  'training for': 16493,
#  'for rural': 10810,
#  'rural folks': 14941,
#  'folks at': 10709,
#  'at Kailali': 7435,
#  'Kailali and': 3258,
#  'and Kanchanpur': 7032,
#  'Kanchanpur https': 3264,
#  'co Veh8rtfD2o': 8846,
#  'Discussion': 1879,
#  'SDG1': 5409,
#  'No': 4398,
#  'Poverty': 4816,
#  'through': 16202,
#  'understand': 16624,
#  'financial': 10599,
#  'inclusion': 11761,
#  'shouldâ': 15256,
#  'tM67oZ96px': 15644,
#  'Discussion on': 1880,
#  'on SDG1': 13797,
#  'SDG1 No': 5410,
#  'No Poverty': 4400,
#  'Poverty through': 4818,
#  'through Financial': 16204,
#  'Inclusion We': 2963,
#  'We need': 6395,
#  'need to': 13356,
#  'to understand': 16437,
#  'understand that': 16625,
#  'that financial': 15801,
#  'financial inclusion': 10605,
#  'inclusion shouldâ': 11767,
#  'shouldâ https': 15257,
#  'co tM67oZ96px': 9244,
#  'Being': 1127,
#  'Birla': 1186,
#  'scion': 15062,
#  'stopping': 15500,
#  'ananya_birla': 7007,
#  'charting': 8204,
#  'her': 11390,
#  'own': 14045,
#  'course': 9563,
#  'musicâ': 13276,
#  'pWI9fQcROI': 14065,
#  'Being Birla': 1128,
#  'Birla scion': 1188,
#  'scion is': 15063,
#  'is not': 12038,
#  'not stopping': 13478,
#  'stopping ananya_birla': 15501,
#  'ananya_birla from': 7008,
#  'from charting': 10915,
#  'charting her': 8205,
#  'her own': 11393,
#  'own course': 14046,
#  'course microfinance': 9565,
#  'microfinance to': 13068,
#  'to musicâ': 16383,
#  'musicâ https': 13277,
#  'co pWI9fQcROI': 9171,
#  'The': 5957,
#  'Asia': 839,
#  'Pacific': 4671,
#  'Forum': 2401,
#  'coming': 9380,
#  'Singapore': 5652,
#  'end': 10210,
#  'this': 16161,
#  'month': 13210,
#  'NextBillion': 4347,
#  'Notes': 4418,
#  'givinâ': 11065,
#  'PjRpibnIWi': 4775,
#  'The Asia': 5959,
#  'Asia Pacific': 841,
#  'Pacific Microfinance': 4672,
#  'Microfinance Forum': 3919,
#  'Forum is': 2404,
#  'is coming': 11998,
#  'coming to': 9382,
#  'to Singapore': 16286,
#  'Singapore at': 5655,
#  'the end': 15944,
#  'end of': 10213,
#  'of this': 13717,
#  'this month': 16172,
#  'month and': 13216,
#  'and NextBillion': 7043,
#  'NextBillion Notes': 4351,
#  'Notes is': 4421,
#  'is givinâ': 12014,
#  'givinâ https': 11066,
#  'co PjRpibnIWi': 8731,
#  'Beth__Sadler': 1148,
#  'FREE': 2256,
#  'event': 10341,
#  'AstonUniversity': 871,
#  '30': 275,
#  'Oct': 4467,
#  '30pm': 285,
#  'history': 11443,
#  'nine': 13420,
#  'archives': 7260,
#  'by': 8001,
#  'Prof': 4863,
#  'Stephanie': 5790,
#  'Decker': 1808,
#  'histoâ': 11445,
#  'RT Beth__Sadler': 4983,
#  'Beth__Sadler FREE': 1149,
#  'FREE event': 2257,
#  'event AstonUniversity': 10342,
#  'AstonUniversity 30': 872,
#  '30 Oct': 279,
#  'Oct 30pm': 4468,
#  '30pm history': 286,
#  'history of': 11444,
#  'of business': 13655,
#  'business in': 7954,
#  'in nine': 11725,
#  'nine archives': 13421,
#  'archives by': 7261,
#  'by Prof': 8011,
#  'Prof Stephanie': 4864,
#  'Stephanie Decker': 5791,
#  'Decker The': 1809,
#  'The histoâ': 5996,
#  'RotimiLawale': 5357,
#  'UPDATE': 6159,
#  'On': 4531,
#  'Joint': 3205,
#  'Farmers': 2281,
#  'Nigeria': 4370,
#  'first': 10671,
#  'farmers': 10499,
#  'met': 12908,
#  'Union': 6224,
#  'wâ': 17242,
#  'RT RotimiLawale': 5102,
#  'RotimiLawale UPDATE': 5360,
#  'UPDATE On': 6160,
#  'On Joint': 4532,
#  'Joint Farmers': 3206,
#  'Farmers Microfinance': 2282,
#  'Bank Nigeria': 1040,
#  'Nigeria first': 4374,
#  'first farmers': 10674,
#  'farmers Microfinance': 10501,
#  'Microfinance bank': 3971,
#  'bank We': 7573,
#  'have met': 11318,
#  'met with': 12909,
#  'with Union': 17087,
#  'Union Bank': 6225,
#  'Bank and': 1051,
#  'and wâ': 7173,
#  'bankingonvalues': 7609,
#  'Do': 1889,
#  'know': 12269,
#  'partner': 14097,
#  'Oikocredit': 4515,
#  'They': 6031,
#  'worldwide': 17212,
#  'cooperative': 9516,
#  'social': 15348,
#  'investor': 11955,
#  'providing': 14482,
#  'funding': 10950,
#  'miâ': 13169,
#  'RT bankingonvalues': 5142,
#  'bankingonvalues Do': 7610,
#  'Do you': 1893,
#  'you know': 17330,
#  'know our': 12274,
#  'our partner': 13996,
#  'partner Oikocredit': 14098,
#  'Oikocredit They': 4516,
#  'They are': 6032,
#  'are worldwide': 7311,
#  'worldwide cooperative': 17213,
#  'cooperative and': 9517,
#  'and social': 7145,
#  'social investor': 15355,
#  'investor providing': 11956,
#  'providing funding': 14485,
#  'funding to': 10956,
#  'to the': 16429,
#  'the miâ': 16015,
#  'joined': 12171,
#  'board': 7844,
#  'today': 16447,
#  'Africa': 656,
#  'approved': 7255,
#  'CBN': 1312,
#  'mâ': 13299,
#  'RotimiLawale joined': 5361,
#  'joined the': 12173,
#  'the board': 15911,
#  'board of': 7845,
#  'of Joint': 13606,
#  'Bank today': 1064,
#  'today first': 16454,
#  'bank in': 7581,
#  'in Africa': 11621,
#  'Africa approved': 658,
#  'approved by': 7256,
#  'by CBN': 8003,
#  'CBN mâ': 1318,
#  'Know': 3326,
#  'relish': 14755,
#  'convey': 9512,
#  'marvellous': 12830,
#  'preferred': 14355,
#  'narrations': 13330,
#  'Mobilize': 4088,
#  'Women': 6492,
#  'Progress': 4877,
#  'Is': 3073,
#  'Assured': 869,
#  'YADIOhXseK': 6553,
#  'Know relish': 3327,
#  'relish amp': 14756,
#  'amp convey': 6971,
#  'convey marvellous': 9513,
#  'marvellous preferred': 12831,
#  'preferred narrations': 14356,
#  'narrations in': 13331,
#  'in Mobilize': 11656,
#  'Mobilize Women': 4089,
#  'Women Progress': 6495,
#  'Progress Is': 4878,
#  'Is Assured': 3074,
#  'Assured https': 870,
#  'co YADIOhXseK': 8885,
#  'theâ': 16152,
#  'ESiOJY753n': 1986,
#  'to theâ': 16432,
#  'theâ https': 16153,
#  'co ESiOJY753n': 8556,
#  'BIMAS': 958,
#  'Registry': 5292,
#  'Assistant': 858,
#  'Embu': 2057,
#  'Job': 3165,
#  'Kenya': 3289,
#  'Limited': 3518,
#  'leading': 12426,
#  'microâ': 13119,
#  'CJ3AorYVXQ': 1371,
#  'BIMAS Registry': 961,
#  'Registry Assistant': 5293,
#  'Assistant Jobs': 861,
#  'Jobs in': 3185,
#  'in Embu': 11638,
#  'Embu Registry': 2059,
#  'Assistant Job': 860,
#  'Job at': 3173,
#  'at BIMAS': 7427,
#  'BIMAS Kenya': 960,
#  'Kenya BIMAS': 3290,
#  'Kenya Limited': 3293,
#  'Limited leading': 3531,
#  'leading microâ': 12431,
#  'microâ https': 13120,
#  'co CJ3AorYVXQ': 8504,
#  'cacedebu': 8046,
#  'CACEDEBU': 1304,
#  'va': 16742,
#  'procÃ': 14396,
#  'der': 9822,
#  'ouverture': 14026,
#  'officielle': 13761,
#  'CAPEDEBU': 1308,
#  'ce': 8142,
#  '12': 88,
#  'octobre': 13566,
#  '2018': 176,
#  'Une': 6216,
#  'mise': 13157,
#  'placâ': 14225,
#  'RT cacedebu': 5148,
#  'cacedebu CACEDEBU': 8047,
#  'CACEDEBU va': 1305,
#  'va procÃ': 16743,
#  'procÃ der': 14397,
#  'der ouverture': 9823,
#  'ouverture officielle': 14027,
#  ...}

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_bigrams, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_bigrams)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 91.47%'

# %% [markdown]
# As expected, adding bigrams slightly improves the accuracy of our Naive Bayes model.<br>

# %% [markdown]
# # Improvement 3: Binary count Naive Bayes
#
# Another improvement specific to sentiment analysis is binary count. Using binary count Naive Bayes isn't guaranteed to improve your model, but it frequently does when sentiment analysis is involved. To incorporate this to our model, we will update the text_process function to remove duplicates.

# %%
#update the text_process function to get rid of duplicates in the reviews

def text_process_binary(text):
    '''
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Return the cleaned lemmatized text as a list of words
    '''
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    nostopwords = [lemmatizer.lemmatize(word) for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return list(set(nostopwords))

# %%
#Use bigrams with countvectorizer
vectorizer_binary = CountVectorizer(analyzer=text_process_binary)
train_features_binary = vectorizer_binary.fit_transform(train['Comments'])
test_features_binary =  vectorizer_binary.transform(test['Comments'])

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_binary, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_binary)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 89.34%'

# %% [markdown]
# Unfortunately, adding binary count does not improve the accuracy of our Naive Bayes model in this sample of data.<br>

# %% [markdown]
# # Improvement 4: Dealing with informal text
# Lastly, another improvement specific to sentiment analysis is to deal more specifically with informal test. Common informal text related to sentiment analysis are emojis and informal text, like all caps, to represent excitement. To deal with emojis, we will update our text_process function, and to deal with capitalization, we will turn off the lowercase parameter in the CountVectorizer initializer. Given wordnet did not consider capitalization and emojis when classifying the data in the first place, this method will unfortunately probably not change the accuracy of the model.

# %%
#all capitalized phrases are taken into account as a different word, but accounting for simple emojis is helpful

def text_process_informal(text):
    '''
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Return the cleaned text as a list of lemmatized words
    '''
    nopunc = [text[i] for i in range(len(text)) if (text[i] not in string.punctuation) or \
              (text[i:i+2] in [":(", ":)"]) or (text[i]+text[i-1] in [":(", ":)"]) or \
              (text[i:i+2] in ["(:", "):"]) or (text[i]+text[i-1] in ["(:", "):"])]
    nopunc = ''.join(nopunc)
    
    nostopwords = [lemmatizer.lemmatize(word) for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return nostopwords

# %%
#test on a sample text  to make sure the update worked
text = ":I LOVE love BBQ chicken pizza. I eat it every day, but sometimes I wonder if I'm being unhealthy :) :("
text_process_informal(text)
# Out:
# [':I',
#  'LOVE',
#  'love',
#  'BBQ',
#  'chicken',
#  'pizza',
#  'eat',
#  'every',
#  'day',
#  'sometimes',
#  'wonder',
#  'Im',
#  'unhealthy',
#  ':)',
#  ':(']

# %%
#Use bigrams with countvectorizer
vectorizer_informal = CountVectorizer(analyzer=text_process_informal, lowercase = False)
train_features_informal = vectorizer_informal.fit_transform(train['Comments'])
test_features_informal =  vectorizer_informal.transform(test['Comments'])

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_informal, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_informal)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 88.95%'

# %% [markdown]
# As predicted, the accuracy did not change from basic Naive Bayes.

# %% [markdown]
# # Conclusion
#
# We've reviewed the basics of Naive Bayes and investigated how improvements can be used in the case of sentiment analysis. Our results are a bit skewed due to the methodology of original classification, but it seems that using bigrams (or any form of ngrams) was the most effective way to improve the model.
#
# We hope that this module has taught you that real life data is messy, and that building a model is more an art than a science. There are many kinds of small improvements you can make to a Naive Bayes model, and it often depends on the nature of your data. For instance, if you know the text you're using will be particularly informal, it may be good to adapt your analyzer function to account for those informalities. If the text is not informal, this adjustment will not change much to your model accuracy.

# %% [markdown]
# Sources: https://medium.com/tensorist/classifying-yelp-reviews-using-nltk-and-scikit-learn-c58e71e962d9, https://www.dataquest.io/blog/naive-bayes-tutorial/, http://nlpforhackers.io/sentiment-analysis-intro/, http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html <br>
